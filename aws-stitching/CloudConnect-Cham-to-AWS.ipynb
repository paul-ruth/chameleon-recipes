# %% [markdown]
# # Internet2 CloudConnect with AWS Direct Connect using Jupyter Notebooks

# %% [markdown]
# <div class="alert alert-info">
#
# **Note:**    AWS Direct Connect functionality requires a more hands-on approach and some manual steps. Assistance from the Chameleon team is likely required, especially if you do not have access to Internet2's CloudConnect portal. Please reach out if you're interested in working on a setup like this.
#
# </div>
#
# ## Background
#
# Network configuration is a critical element of any experiment spanning research and commercial clouds. The most common option is to assign domain specific public Internet addresses to all nodes and send traffic over the traditional Internet.  This approach is adequate for many experiment but suffers from security and performance limitations. Another option is to use a virtual private network (VPN) as a tunnel between distributed sites; the VPN protects the architecture from common security attacks and allows remote cloud resources to be assigned local IP addresses and managed as if they were on-site. Both of these options have the advantage of easy implementation, but are limited by the performance of the public Internet, an important consideration for many experiments.
#
# Many computer science experiments require increased control of the wide area network, include everything from garunteed quality of service to low-level network programability using software defined networking.  Chameleon provides these capabilities though direct low-level network connection between the research and public clouds, however creating them is challenging. While most public clouds provide low-level networking services (e.g. [AWS Direct Connect](https://aws.amazon.com/directconnect/), [Azure ExpressRoute](https://azure.microsoft.com/en-us/services/expressroute/), or [Google Dedicated Interconnect](https://cloud.google.com/network-connectivity/docs/interconnect/concepts/dedicated-overview)), using them is typically expensive; on the research cloud side, they can involve complicated campus network configuration arrangements that often limit access to this type of experimental configuration to a few a few select scientists or campus IT staff themselves.
#
# Since 2016, the Chameleon testbed has provided direct connect using Internet2’s [Advanced Layer 2 service (AL2S)](https://www.internet2.edu/products-services/advanced-networking/layer-2-services/) via [ExoGENI](http://www.exogeni.net/). More recently, Internet2 has deployed its [CloudConnect](https://www.internet2.edu/products-services/advanced-networking/networking-for-cloud/) service that enables members to connect end points, such as those used for Chameleon direct AL2S connections, to AWS Direct Connect, Azure ExpressRoute, and Google Dedicated Interconnect sites. Thus, to create an experimental topology between Chameleon and commercial cloud the first step is to create a direct connection between Chameleon and a public cloud accessible using Internet2’s CloudConnect. Additionally, since public cloud direct connections configure routing between the cloud and external facility using BGP, a user also needs to deploy a BGP router on their resources.
#
# This Jupyter notebook walks through the deployment of an experiment spanning Chameleon and AWS using CloudConnect.  It deploys the network, compute servers, and a fully configured BGP router. Further, the BGP router can, optionally, be deployed on a dedicated OpenFlow networking switch or as software Quagga router existing on a standard x86 compute host.  The full networking configuration is depicted in the figure below.
#
# <br>
# <center>
#     <img src="./CloudConnect-Figs/ChameleonCloudConnectSW.png"><br>
#     <em>Experiment spanning Chameleon and AWS using Internet2 CloudConnect</em>
# </center>
# <br>
#
# The configuration of the experiment can be seen in the figure.  A BGP router was deployed on a Chameleon host connected
# to two dedicated 10 Gbps tenant networks. One was an externally connected network that was stitched to an Internet2 CloudConnect BGP router. The other was an internal network connected to other compute nodes on Chameleon. On the AWS side, the CloudConnect BGP router was connected to a Virtual Private Gateway (VPG). The router in a Virtual Private Cloud (VPC) was configured with default routes to a private
# Internet Gateway and custom routes through the dedicated Internet2 circuit to the isolated tenant network on Chameleon. The three BGP  routers cooperate to advertise routes between user-controlled subnets hosted on Chameleon and AWS. The infrastructure’s configuration is described in the Chameleon tutorial on using Internet2 CloudConnect.
#
# ## Tutorial
#
# There are three components of the deployed infrastructure: Chameleon, AWS, and CloudConnect. Each step is described in the following sections. The configuration parameteres using in the example are shown in the following figure.
#
# <br>
# <center>
#     <img src="./CloudConnect-Figs/AWS-Config.png"><br>
#     <em>Configuration Parameters</em>
# </center>
# <br>
#
# #### Set the configuration variables

# %%
# Project name and targeted region
export OS_PROJECT_NAME='CH-816532'
export OS_REGION_NAME='CHI@UC'

# Any key you have uploaded to Chameleon
export KEY_NAME='my_chameleon_key'

# Location of the matching private key in your Jupyter container
export PRIVATE_KEY_LOCATION="/home/${USER}/work/my_chameleon_key"

# Set a preface to be used to identify named experiment objects in Chameleon
# You username is a good PREFACE.
export PREFACE=${USER}

#Desired name of the direct connect circuit
DIRECT_CONNECT_NAME="Chameleon_Direct_Connect"

# AWS VPC Network
# Name of EXISTING VPC in your AWS account
export AWS_VPC_NAME="Chameleon_Direct_Connect_VPC"
export AWS_INTERNAL_SUBNET="192.168.1.0/24"
export AWS_VLAN=10

# Chameleon-to-AWS Network (i.e. "External Network")
export EXTERNAL_SUBNET="192.168.3.0/24" 
export EXTERNAL_NET_INTERNET_GATEWAY_IP="192.168.3.254"

# Chameleon Internal Network
export CHAMELEON_INTERNAL_SUBNET="192.168.4.0/24" 
export CHAMELEON_INTERNAL_SUBNET_ESC="192.168.4.0\/24"  
export CHAMELEON_INTERNAL_NET_INTERNET_GATEWAY_IP="192.168.4.254"
export CHAMELEON_INTERNAL_NET_DHCP_ALLOCATION_START="192.168.4.100"
export CHAMELEON_INTERNAL_NET_DHCP_ALLOCATION_END="192.168.4.200"

# AWS 
export AWS_ASN="65001"
export AWS_ROUTER_EXTERNAL_IP="192.168.3.2"
export AWS_ROUTER_EXTERNAL_IP_CIDR=${AWS_ROUTER_EXTERNAL_IP}/24
export AWS_BGP_PASSWORD="BgpAuthPass"

# Chameleon 
export CHAMELEON_ASN="65002"
export CHAMELEON_ROUTER_IP_FACING_AWS="192.168.3.1"
export CHAMELEON_ROUTER_IP_FACING_INTERNAL="192.168.4.1"
export CHAMELEON_ROUTER_IP_FACING_AWS_CIDR=${CHAMELEON_ROUTER_IP_FACING_AWS}/24

export BGP_PASSWORD="BgpAuthPass"


# AWS Configuration
# To get your keys see: https://docs.aws.amazon.com/cli/latest/userguide/cli-configure-quickstart.html
# The following assumes the .csv aquired from AWS is placed in your notebook's ~/work folder but hardcoding 
# the values here will also work.
AWS_ACCESS_KEY_ID=`tail -n +2  ~/work/new_user_credentials.csv | cut -d, -f1`
AWS_SECRRET_ACCESS_KEY=`tail -n +2  ~/work/new_user_credentials.csv | cut -d, -f2`

DEFAULT_REGION_NAME='us-east-2'
DEFAULT_OUTPUT_FORMAT='json'

# %% [markdown]
# ### Chameleon Configuration
#
# First, we show how the create the Chameleon resources.
#
# #### Create Chameleon networks
#
# On Chameleon there are two separate networks. The external network connects to Internet2 while the internal network connects local Chameleon nodes. Later we will creata a BGP router that will route network traffic between these networks.
#
# ##### Create the external network
#
# The external network must be able to stitch to an external exogeni stitchport. This is achomplished by reserving an externally stitchable isolated network and setting the provider network to exogeni. We will be managing our own router for this network and do not need Chameleon to create one for us.

# %%
#Set the names of the lease and network
EXTERNAL_NET_LEASE_NAME="${PREFACE}-AWS-Network-External-Lease"
EXTERNAL_NET_NAME="${PREFACE}-AWS-Network-External-Network"

#Set the provider network 
PROVIDER="exogeni"

blazar lease-create \
   --reservation resource_type=network,network_name=${EXTERNAL_NET_NAME},resource_properties="[\"==\",\"\$physical_network\",\"$PROVIDER\"]" \
   ${EXTERNAL_NET_LEASE_NAME}
# Out:
# Matches: ('resource_type=network,network_name=pruth-AWS-Network-External-Network', 'resource_properties', '["==","$physical_network","exogeni"]')
# Matches: ('resource_type=network', 'network_name', 'pruth-AWS-Network-External-Network')
# Matches: (None, 'resource_type', 'network')
# Created a new lease:
# +--------------+------------------------------------------------------------------+
# | Field        | Value                                                            |
# +--------------+------------------------------------------------------------------+
# | created_at   | 2020-09-25 16:18:42                                              |
# | degraded     | False                                                            |
# | end_date     | 2020-09-26T16:18:00.000000                                       |
# | events       | {                                                                |
# |              |     "status": "UNDONE",                                          |
# |              |     "lease_id": "741e35b2-3699-40d2-9ff8-c27170d4be0f",          |
# |              |     "event_type": "start_lease",                                 |
# |              |     "created_at": "2020-09-25 16:18:45",                         |
# |              |     "updated_at": null,                                          |
# |              |     "time": "2020-09-25T16:18:00.000000",                        |
# |              |     "id": "35e4f84f-8a2a-4fd0-af5f-60df0279af86"                 |
# |              | }                                                                |
# |              | {                                                                |
# |              |     "status": "UNDONE",                                          |
# |              |     "lease_id": "741e35b2-3699-40d2-9ff8-c27170d4be0f",          |
# |              |     "event_type": "before_end_lease",                            |
# |              |     "created_at": "2020-09-25 16:18:45",                         |
# |              |     "updated_at": null,                                          |
# |              |     "time": "2020-09-25T16:18:00.000000",                        |
# |              |     "id": "ada82bb1-45c9-4dda-a781-d55b503bd78c"                 |
# |              | }                                                                |
# |              | {                                                                |
# |              |     "status": "UNDONE",                                          |
# |              |     "lease_id": "741e35b2-3699-40d2-9ff8-c27170d4be0f",          |
# |              |     "event_type": "end_lease",                                   |
# |              |     "created_at": "2020-09-25 16:18:45",                         |
# |              |     "updated_at": null,                                          |
# |              |     "time": "2020-09-26T16:18:00.000000",                        |
# |              |     "id": "ecee909b-2931-437b-8742-cf8c3669497b"                 |
# |              | }                                                                |
# | id           | 741e35b2-3699-40d2-9ff8-c27170d4be0f                             |
# | name         | pruth-AWS-Network-External-Lease                                 |
# | project_id   | 4b6fc5a731a54b6f932b200050f13b54                                 |
# | reservations | {                                                                |
# |              |     "status": "pending",                                         |
# |              |     "lease_id": "741e35b2-3699-40d2-9ff8-c27170d4be0f",          |
# |              |     "resource_id": "afb232e1-6b14-4827-a3ce-68b6bab1e82d",       |
# |              |     "created_at": "2020-09-25 16:18:42",                         |
# |              |     "updated_at": "2020-09-25 16:18:45",                         |
# |              |     "missing_resources": false,                                  |
# |              |     "id": "b133183d-d0f8-43b4-8807-7dd94e63da7d",                |
# |              |     "resource_type": "network",                                  |
# |              |     "resources_changed": false                                   |
# |              | }                                                                |
# | start_date   | 2020-09-25T16:18:00.000000                                       |
# | status       | PENDING                                                          |
# | trust_id     | 80cf9c2b3f064dea9b2e9eb5c93f1cc4                                 |
# | updated_at   | 2020-09-25 16:18:45                                              |
# | user_id      | 02276834a17c4ca205d49eaa8c984eeaefc24c153f8a62bc16e5f880e7cce607 |
# +--------------+------------------------------------------------------------------+

# %%
EXTERNAL_SUBNET_NAME="${PREFACE}-AWS-Network-External-Subnet"
 
openstack subnet create --subnet-range ${EXTERNAL_SUBNET} \
                   --no-dhcp \
                   --gateway ${EXTERNAL_NET_INTERNET_GATEWAY_IP} \
                   --network ${EXTERNAL_NET_NAME} ${EXTERNAL_SUBNET_NAME}
# Out:
# +----------------------+--------------------------------------+
# | Field                | Value                                |
# +----------------------+--------------------------------------+
# | allocation_pools     | 192.168.3.1-192.168.3.253            |
# | cidr                 | 192.168.3.0/24                       |
# | created_at           | 2020-09-25T16:19:06Z                 |
# | description          |                                      |
# | dns_nameservers      |                                      |
# | dns_publish_fixed_ip | None                                 |
# | enable_dhcp          | False                                |
# | gateway_ip           | 192.168.3.254                        |
# | host_routes          |                                      |
# | id                   | 325b816e-71fa-4c5a-8cd5-73e8acc492d3 |
# | ip_version           | 4                                    |
# | ipv6_address_mode    | None                                 |
# | ipv6_ra_mode         | None                                 |
# | name                 | pruth-AWS-Network-External-Subnet    |
# | network_id           | 65ccaddd-e7c9-40f7-b488-ed6e4e64db53 |
# | prefix_length        | None                                 |
# | project_id           | 4b6fc5a731a54b6f932b200050f13b54     |
# | revision_number      | 0                                    |
# | segment_id           | None                                 |
# | service_types        |                                      |
# | subnetpool_id        | None                                 |
# | tags                 |                                      |
# | updated_at           | 2020-09-25T16:19:06Z                 |
# +----------------------+--------------------------------------+

# %% [markdown]
# ##### Create the internal network
#
# The internal network connects to local Chameleon nodes.  This is achomplished by reserving an isolated network and setting the provider network to physnet1. The subnet and router for the internal network will be used by the nodes to access the public Internet.
#
# The internal network can, optionally, be an OpenFlow network or even a stichable network. The example below uses a standared isolated VLAN.

# %%
#Set the names of the lease and network
INTERNAL_NET_LEASE_NAME="${USER}-AWS-Network-Internal-Lease"
INTERNAL_NET_NAME="${USER}-AWS-Network-Internal-Name"

#Set the provider network 
PROVIDER="physnet1"
    
blazar lease-create \
   --reservation resource_type=network,network_name=${INTERNAL_NET_NAME},resource_properties="[\"==\",\"\$physical_network\",\"$PROVIDER\"]" \
   ${INTERNAL_NET_LEASE_NAME}
# Out:
# Matches: ('resource_type=network,network_name=pruth-AWS-Network-Internal-Name', 'resource_properties', '["==","$physical_network","physnet1"]')
# Matches: ('resource_type=network', 'network_name', 'pruth-AWS-Network-Internal-Name')
# Matches: (None, 'resource_type', 'network')
# Created a new lease:
# +--------------+------------------------------------------------------------------+
# | Field        | Value                                                            |
# +--------------+------------------------------------------------------------------+
# | created_at   | 2020-09-25 16:19:11                                              |
# | degraded     | False                                                            |
# | end_date     | 2020-09-26T16:19:00.000000                                       |
# | events       | {                                                                |
# |              |     "status": "UNDONE",                                          |
# |              |     "lease_id": "b0e03a89-7c6a-4e42-9229-faea54838c2f",          |
# |              |     "event_type": "before_end_lease",                            |
# |              |     "created_at": "2020-09-25 16:19:13",                         |
# |              |     "updated_at": null,                                          |
# |              |     "time": "2020-09-25T16:19:00.000000",                        |
# |              |     "id": "1153979b-23e1-4d9c-9ab4-438938c51c82"                 |
# |              | }                                                                |
# |              | {                                                                |
# |              |     "status": "UNDONE",                                          |
# |              |     "lease_id": "b0e03a89-7c6a-4e42-9229-faea54838c2f",          |
# |              |     "event_type": "start_lease",                                 |
# |              |     "created_at": "2020-09-25 16:19:13",                         |
# |              |     "updated_at": null,                                          |
# |              |     "time": "2020-09-25T16:19:00.000000",                        |
# |              |     "id": "884bf3e3-fea1-4ed6-a494-8828c37d05a5"                 |
# |              | }                                                                |
# |              | {                                                                |
# |              |     "status": "UNDONE",                                          |
# |              |     "lease_id": "b0e03a89-7c6a-4e42-9229-faea54838c2f",          |
# |              |     "event_type": "end_lease",                                   |
# |              |     "created_at": "2020-09-25 16:19:13",                         |
# |              |     "updated_at": null,                                          |
# |              |     "time": "2020-09-26T16:19:00.000000",                        |
# |              |     "id": "d63b61d9-0895-4089-a401-cbb7c0d47285"                 |
# |              | }                                                                |
# | id           | b0e03a89-7c6a-4e42-9229-faea54838c2f                             |
# | name         | pruth-AWS-Network-Internal-Lease                                 |
# | project_id   | 4b6fc5a731a54b6f932b200050f13b54                                 |
# | reservations | {                                                                |
# |              |     "status": "pending",                                         |
# |              |     "lease_id": "b0e03a89-7c6a-4e42-9229-faea54838c2f",          |
# |              |     "resource_id": "04a21769-e1fa-4389-a3aa-49836d9c1b03",       |
# |              |     "created_at": "2020-09-25 16:19:11",                         |
# |              |     "updated_at": "2020-09-25 16:19:13",                         |
# |              |     "missing_resources": false,                                  |
# |              |     "id": "c07542de-5c23-49f9-9104-125c8cdddd49",                |
# |              |     "resource_type": "network",                                  |
# |              |     "resources_changed": false                                   |
# |              | }                                                                |
# | start_date   | 2020-09-25T16:19:00.000000                                       |
# | status       | PENDING                                                          |
# | trust_id     | 00dc0b7ba8c94ffd8bbd24fd25fb22ae                                 |
# | updated_at   | 2020-09-25 16:19:13                                              |
# | user_id      | 02276834a17c4ca205d49eaa8c984eeaefc24c153f8a62bc16e5f880e7cce607 |
# +--------------+------------------------------------------------------------------+

# %%
INTERNAL_NET_SUBNET_NAME="${PREFACE}-AWS-Network-Internal-Subnet"
INTERNAL_NET_ROUTER_NAME="${PREFACE}-AWS-Network-Internal-Router"
                   
openstack subnet create --subnet-range ${CHAMELEON_INTERNAL_SUBNET} \
                   --dhcp \
                   --allocation-pool start=${CHAMELEON_INTERNAL_NET_DHCP_ALLOCATION_START},end=${CHAMELEON_INTERNAL_NET_DHCP_ALLOCATION_END} \
                   --gateway ${CHAMELEON_INTERNAL_NET_INTERNET_GATEWAY_IP} \
                   --network ${INTERNAL_NET_NAME} \
                   ${INTERNAL_NET_SUBNET_NAME}
                   
# Set the name of the public network for Internet access
PUBLIC_NET="public"

openstack router create ${INTERNAL_NET_ROUTER_NAME}
openstack router add subnet ${INTERNAL_NET_ROUTER_NAME} ${INTERNAL_NET_SUBNET_NAME} 
openstack router set --external-gateway ${PUBLIC_NET} ${INTERNAL_NET_ROUTER_NAME}

# Set an external subnet that will be routed to the local BGP gateway instead of the default gateway.
# This subnet must include the subnet used on AWS.
openstack subnet set --host-route destination=${AWS_INTERNAL_SUBNET},gateway=${CHAMELEON_ROUTER_IP_FACING_INTERNAL} ${INTERNAL_NET_SUBNET_NAME}
# Out:
# +----------------------+--------------------------------------+
# | Field                | Value                                |
# +----------------------+--------------------------------------+
# | allocation_pools     | 192.168.4.100-192.168.4.200          |
# | cidr                 | 192.168.4.0/24                       |
# | created_at           | 2020-09-25T16:19:49Z                 |
# | description          |                                      |
# | dns_nameservers      |                                      |
# | dns_publish_fixed_ip | None                                 |
# | enable_dhcp          | True                                 |
# | gateway_ip           | 192.168.4.254                        |
# | host_routes          |                                      |
# | id                   | a6c69f2c-32b9-44b1-b066-6a4c82058370 |
# | ip_version           | 4                                    |
# | ipv6_address_mode    | None                                 |
# | ipv6_ra_mode         | None                                 |
# | name                 | pruth-AWS-Network-Internal-Subnet    |
# | network_id           | ffb8b15e-5d89-4e23-b53e-db8adf9363d8 |
# | prefix_length        | None                                 |
# | project_id           | 4b6fc5a731a54b6f932b200050f13b54     |
# | revision_number      | 0                                    |
# | segment_id           | None                                 |
# | service_types        |                                      |
# | subnetpool_id        | None                                 |
# | tags                 |                                      |
# | updated_at           | 2020-09-25T16:19:49Z                 |
# +----------------------+--------------------------------------+
# +-------------------------+--------------------------------------+
# | Field                   | Value                                |
# +-------------------------+--------------------------------------+
# | admin_state_up          | UP                                   |
# | availability_zone_hints |                                      |
# | availability_zones      |                                      |
# | created_at              | 2020-09-25T16:19:52Z                 |
# | description             |                                      |
# | external_gateway_info   | null                                 |
# | flavor_id               | None                                 |
# | id                      | 5ee5440d-8586-4ce1-8a18-f803af701220 |
# | name                    | pruth-AWS-Network-Internal-Router    |
# | project_id              | 4b6fc5a731a54b6f932b200050f13b54     |
# | revision_number         | 1                                    |
# | routes                  |                                      |
# | status                  | ACTIVE                               |
# | tags                    |                                      |
# | updated_at              | 2020-09-25T16:19:52Z                 |
# +-------------------------+--------------------------------------+

# %% [markdown]
# #### Create a lease for floating IP addresses.

# %%
FLOATING_IP_LEASE_NAME="${USER}-AWS-BGP-FloatingIP"

AMOUNT="1"

PUBLIC_NETWORK_ID=$(openstack network show public -f value -c id)

blazar lease-create \
  --reservation "resource_type=virtual:floatingip,network_id=${PUBLIC_NETWORK_ID},amount=${AMOUNT}" \
  "$FLOATING_IP_LEASE_NAME"
# Out:
# Matches: ('resource_type=virtual:floatingip,network_id=44b38c44-2a42-4b6d-b129-6c8f1b2a1375', 'amount', '1')
# Matches: ('resource_type=virtual:floatingip', 'network_id', '44b38c44-2a42-4b6d-b129-6c8f1b2a1375')
# Matches: (None, 'resource_type', 'virtual:floatingip')
# Created a new lease:
# +--------------+------------------------------------------------------------------+
# | Field        | Value                                                            |
# +--------------+------------------------------------------------------------------+
# | created_at   | 2020-09-25 16:20:30                                              |
# | degraded     | False                                                            |
# | end_date     | 2020-09-26T16:20:00.000000                                       |
# | events       | {                                                                |
# |              |     "status": "UNDONE",                                          |
# |              |     "lease_id": "d11a9733-ed26-4e60-a6e1-ba41ebae887e",          |
# |              |     "event_type": "before_end_lease",                            |
# |              |     "created_at": "2020-09-25 16:20:31",                         |
# |              |     "updated_at": null,                                          |
# |              |     "time": "2020-09-25T16:20:00.000000",                        |
# |              |     "id": "5cdf6cd5-2fe8-4a53-9709-2cf0fdadbec6"                 |
# |              | }                                                                |
# |              | {                                                                |
# |              |     "status": "UNDONE",                                          |
# |              |     "lease_id": "d11a9733-ed26-4e60-a6e1-ba41ebae887e",          |
# |              |     "event_type": "start_lease",                                 |
# |              |     "created_at": "2020-09-25 16:20:31",                         |
# |              |     "updated_at": null,                                          |
# |              |     "time": "2020-09-25T16:20:00.000000",                        |
# |              |     "id": "73c7920f-05cc-46cd-92a4-856df7519df5"                 |
# |              | }                                                                |
# |              | {                                                                |
# |              |     "status": "UNDONE",                                          |
# |              |     "lease_id": "d11a9733-ed26-4e60-a6e1-ba41ebae887e",          |
# |              |     "event_type": "end_lease",                                   |
# |              |     "created_at": "2020-09-25 16:20:31",                         |
# |              |     "updated_at": null,                                          |
# |              |     "time": "2020-09-26T16:20:00.000000",                        |
# |              |     "id": "bb96c40f-9506-4727-b06a-194cef21f21b"                 |
# |              | }                                                                |
# | id           | d11a9733-ed26-4e60-a6e1-ba41ebae887e                             |
# | name         | pruth-AWS-BGP-FloatingIP                                         |
# | project_id   | 4b6fc5a731a54b6f932b200050f13b54                                 |
# | reservations | {                                                                |
# |              |     "status": "pending",                                         |
# |              |     "lease_id": "d11a9733-ed26-4e60-a6e1-ba41ebae887e",          |
# |              |     "resource_id": "1dba9f9d-4194-4a1a-b8fe-52a6fa1e54c1",       |
# |              |     "network_id": "44b38c44-2a42-4b6d-b129-6c8f1b2a1375",        |
# |              |     "created_at": "2020-09-25 16:20:30",                         |
# |              |     "updated_at": "2020-09-25 16:20:31",                         |
# |              |     "required_floatingips": [],                                  |
# |              |     "missing_resources": false,                                  |
# |              |     "amount": 1,                                                 |
# |              |     "id": "e914cf51-d89c-4893-96a9-4fa760270659",                |
# |              |     "resource_type": "virtual:floatingip",                       |
# |              |     "resources_changed": false                                   |
# |              | }                                                                |
# | start_date   | 2020-09-25T16:20:00.000000                                       |
# | status       | PENDING                                                          |
# | trust_id     | dc8b40c5e71a4ec2bd48aec0b3601518                                 |
# | updated_at   | 2020-09-25 16:20:31                                              |
# | user_id      | 02276834a17c4ca205d49eaa8c984eeaefc24c153f8a62bc16e5f880e7cce607 |
# +--------------+------------------------------------------------------------------+

# %% [markdown]
# #### Create the BGP router
# In this setup, 2 instances are created.
# 	BGP speaker (sw-bgp) is an instance that is built on a dual-nic Haswell node.
# Regular node (sw-instance-1) in the subnet can be built on a Skylake or Haswell node.
#
# Create a lease with 2-3 dual-nic Haswell nodes.

# %%
# Create Lease for the BGP router.
# Requires 1 Haswell Node with dual-NICs enabled
#
BGP_ROUTER_LEASE_NAME="${USER}-AWS-BGP-Router-Lease" 

NODE_TYPE="compute_haswell"
MIN=1
MAX=1

blazar lease-create \
      --physical-reservation min=${MIN},max=${MAX},resource_properties="[\"and\",[\"==\",\"\$network_adapters.1.enabled\",\"True\"],[\"==\",\"\$node_type\",\"compute_haswell\"]]" \
      ${BGP_ROUTER_LEASE_NAME}
# Out:
# Matches: ('min=1,max=1', 'resource_properties', '["and",["==","$network_adapters.1.enabled","True"],["==","$node_type","compute_haswell"]]')
# Matches: ('min=1', 'max', '1')
# Matches: (None, 'min', '1')
# Created a new lease:
# +--------------+---------------------------------------------------------------------------------------------------------------------------------------+
# | Field        | Value                                                                                                                                 |
# +--------------+---------------------------------------------------------------------------------------------------------------------------------------+
# | created_at   | 2020-09-25 16:20:42                                                                                                                   |
# | degraded     | False                                                                                                                                 |
# | end_date     | 2020-09-26T16:20:00.000000                                                                                                            |
# | events       | {                                                                                                                                     |
# |              |     "status": "UNDONE",                                                                                                               |
# |              |     "lease_id": "f83adf11-928c-44f8-996c-35ec37da3eaa",                                                                               |
# |              |     "event_type": "start_lease",                                                                                                      |
# |              |     "created_at": "2020-09-25 16:20:50",                                                                                              |
# |              |     "updated_at": null,                                                                                                               |
# |              |     "time": "2020-09-25T16:20:00.000000",                                                                                             |
# |              |     "id": "021c8ef7-8909-4b8c-b9d9-7eaa64285acd"                                                                                      |
# |              | }                                                                                                                                     |
# |              | {                                                                                                                                     |
# |              |     "status": "UNDONE",                                                                                                               |
# |              |     "lease_id": "f83adf11-928c-44f8-996c-35ec37da3eaa",                                                                               |
# |              |     "event_type": "end_lease",                                                                                                        |
# |              |     "created_at": "2020-09-25 16:20:52",                                                                                              |
# |              |     "updated_at": null,                                                                                                               |
# |              |     "time": "2020-09-26T16:20:00.000000",                                                                                             |
# |              |     "id": "0d20ea1b-d312-405b-acbb-7b1fc9ae29b8"                                                                                      |
# |              | }                                                                                                                                     |
# |              | {                                                                                                                                     |
# |              |     "status": "UNDONE",                                                                                                               |
# |              |     "lease_id": "f83adf11-928c-44f8-996c-35ec37da3eaa",                                                                               |
# |              |     "event_type": "before_end_lease",                                                                                                 |
# |              |     "created_at": "2020-09-25 16:20:52",                                                                                              |
# |              |     "updated_at": null,                                                                                                               |
# |              |     "time": "2020-09-25T16:20:00.000000",                                                                                             |
# |              |     "id": "5bfc0aad-7499-4c7d-b60e-1d678e4694b1"                                                                                      |
# |              | }                                                                                                                                     |
# | id           | f83adf11-928c-44f8-996c-35ec37da3eaa                                                                                                  |
# | name         | pruth-AWS-BGP-Router-Lease                                                                                                            |
# | project_id   | 4b6fc5a731a54b6f932b200050f13b54                                                                                                      |
# | reservations | {                                                                                                                                     |
# |              |     "status": "pending",                                                                                                              |
# |              |     "before_end": "default",                                                                                                          |
# |              |     "lease_id": "f83adf11-928c-44f8-996c-35ec37da3eaa",                                                                               |
# |              |     "resource_id": "930f8f94-5fa2-4871-9918-f3fc550ba236",                                                                            |
# |              |     "max": 1,                                                                                                                         |
# |              |     "created_at": "2020-09-25 16:20:42",                                                                                              |
# |              |     "min": 1,                                                                                                                         |
# |              |     "updated_at": "2020-09-25 16:20:50",                                                                                              |
# |              |     "missing_resources": false,                                                                                                       |
# |              |     "hypervisor_properties": "",                                                                                                      |
# |              |     "on_start": "default",                                                                                                            |
# |              |     "resource_properties": "[\"and\",[\"==\",\"$network_adapters.1.enabled\",\"True\"],[\"==\",\"$node_type\",\"compute_haswell\"]]", |
# |              |     "id": "f63d297c-119d-4cf2-9162-c05c5db93814",                                                                                     |
# |              |     "resource_type": "physical:host",                                                                                                 |
# |              |     "resources_changed": false                                                                                                        |
# |              | }                                                                                                                                     |
# | start_date   | 2020-09-25T16:20:00.000000                                                                                                            |
# | status       | PENDING                                                                                                                               |
# | trust_id     | fadd660f04ec46bf90ef825b716f320e                                                                                                      |
# | updated_at   | 2020-09-25 16:20:52                                                                                                                   |
# | user_id      | 02276834a17c4ca205d49eaa8c984eeaefc24c153f8a62bc16e5f880e7cce607                                                                      |
# +--------------+---------------------------------------------------------------------------------------------------------------------------------------+

# %%
# Get the reservation ID
BGP_ROUTER_RESERVATION_ID=$(blazar lease-show  -f json ${BGP_ROUTER_LEASE_NAME} | jq -r .reservations | jq -r .id)
BGP_ROUTER_LEASE_ID=$(blazar lease-show  -f json ${BGP_ROUTER_LEASE_NAME} | jq -r .id)

# Get network UUIDs
NET_UUID_INTERNAL=$( openstack network show -f value -c id ${INTERNAL_NET_NAME} )
NET_UUID_EXTERNAL=$( openstack network show -f value -c id ${EXTERNAL_NET_NAME} )

BGP_ROUTER_NAME="${USER}-AWS-BGP-Router" 

FLAVOR="baremetal"
IMAGE="CC-CentOS7"

openstack server create \
  --image ${IMAGE} \
  --flavor ${FLAVOR} \
  --key-name ${KEY_NAME} \
  --nic net-id=${NET_UUID_INTERNAL},v4-fixed-ip=${CHAMELEON_ROUTER_IP_FACING_INTERNAL} \
  --nic net-id=${NET_UUID_EXTERNAL},v4-fixed-ip=${CHAMELEON_ROUTER_IP_FACING_AWS} \
  --hint reservation=${BGP_ROUTER_RESERVATION_ID} \
  --hint query='["=","$hypervisor_hostname","$PHYSICAL"]' \
  ${BGP_ROUTER_NAME}
# Out:
# +-------------------------------------+------------------------------------------------------------------+
# | Field                               | Value                                                            |
# +-------------------------------------+------------------------------------------------------------------+
# | OS-DCF:diskConfig                   | MANUAL                                                           |
# | OS-EXT-AZ:availability_zone         |                                                                  |
# | OS-EXT-SRV-ATTR:host                | None                                                             |
# | OS-EXT-SRV-ATTR:hypervisor_hostname | None                                                             |
# | OS-EXT-SRV-ATTR:instance_name       |                                                                  |
# | OS-EXT-STS:power_state              | NOSTATE                                                          |
# | OS-EXT-STS:task_state               | scheduling                                                       |
# | OS-EXT-STS:vm_state                 | building                                                         |
# | OS-SRV-USG:launched_at              | None                                                             |
# | OS-SRV-USG:terminated_at            | None                                                             |
# | accessIPv4                          |                                                                  |
# | accessIPv6                          |                                                                  |
# | addresses                           |                                                                  |
# | adminPass                           | Npksn8LPVcbA                                                     |
# | config_drive                        |                                                                  |
# | created                             | 2020-09-25T17:32:45Z                                             |
# | flavor                              | baremetal (baremetal)                                            |
# | hostId                              |                                                                  |
# | id                                  | b0affa2a-6dd7-4e4f-a69b-2bc9bbb6a18a                             |
# | image                               | CC-CentOS7 (2feec1df-8523-4a82-92f2-19c39224fa89)                |
# | key_name                            | my_chameleon_key                                                 |
# | name                                | pruth-AWS-BGP-Router                                             |
# | progress                            | 0                                                                |
# | project_id                          | 4b6fc5a731a54b6f932b200050f13b54                                 |
# | properties                          |                                                                  |
# | security_groups                     | name='default'                                                   |
# | status                              | BUILD                                                            |
# | updated                             | 2020-09-25T17:32:48Z                                             |
# | user_id                             | 02276834a17c4ca205d49eaa8c984eeaefc24c153f8a62bc16e5f880e7cce607 |
# | volumes_attached                    |                                                                  |
# +-------------------------------------+------------------------------------------------------------------+

# %% [markdown]
# #### Associate floating IPs with instances.
#
# You must wait for the node to start spawning before you can associate a floating IP.

# %%
BGP_ROUTER_FLOATING_IP=$(lease_list_floating_ips "$FLOATING_IP_LEASE_NAME" | sed -n 1p)

openstack server add floating ip "$BGP_ROUTER_NAME" "$BGP_ROUTER_FLOATING_IP" \
  && echo "Attached floating ip $BGP_ROUTER_FLOATING_IP!"
# Out:
# Attached floating ip 192.5.87.172!

# %% [markdown]
# #### Configure BGP Router
#
# The following script will configure the BGP router node and install a docker container that will communicate with the Internet2 CloudConnect BGP router.

# %%
login_command="ssh -o \"StrictHostKeyChecking no\" -i $PRIVATE_KEY_LOCATION cc@$BGP_ROUTER_FLOATING_IP"

IF_INTERNAL_NET='eth0'
IF_EXTERNAL_NET='eth1'

CHAMELEON_ROUTER_IP_FACING_AWS_CIDR='${CHAMELEON_ROUTER_IP_FACING_AWS}\/24'
CHAMELEON_ROUTER_IP_FACING_INTERNAL_CIDR='${CHAMELEON_ROUTER_IP_FACING_INTERNAL}\/24'

eval "$login_command bash << EOF

echo Configure external iface
sudo ip addr add ${CHAMELEON_ROUTER_IP_FACING_AWS}/24 dev ${IF_EXTERNAL_NET}

sudo ip link set ${IF_INTERNAL_NET} up
sudo ip link set ${IF_INTERNAL_NET} mtu 9000
sudo ip link set ${IF_INTERNAL_NET} txqueuelen 10000

sudo ip link set ${IF_EXTERNAL_NET} up
sudo ip link set ${IF_EXTERNAL_NET} mtu 9000
sudo ip link set ${IF_EXTERNAL_NET} txqueuelen 10000

sudo iptables -I FORWARD -i ${IF_EXTERNAL_NET} -o ${IF_INTERNAL_NET} -m state --state NEW,ESTABLISHED,RELATED -j ACCEPT
sudo iptables -I FORWARD -i ${IF_INTERNAL_NET} -o ${IF_EXTERNAL_NET} -m state --state NEW,ESTABLISHED,RELATED -j ACCEPT 

#Remove the external route because this is the router
sudo ip route del ${AWS_INTERNAL_SUBNET}

sudo sh -c 'echo net.core.rmem_max = 67108864 >> /etc/sysctl.conf'
sudo sh -c 'echo net.core.wmem_max = 67108864  >> /etc/sysctl.conf'
sudo sh -c 'echo net.ipv4.tcp_rmem = 4096 87380 33554432 >> /etc/sysctl.conf'
sudo sh -c 'echo net.ipv4.tcp_wmem = 4096 65536 33554432 >> /etc/sysctl.conf'
sudo sh -c 'echo net.ipv4.tcp_congestion_control=htcp >> /etc/sysctl.conf'
sudo sh -c 'echo net.ipv4.tcp_mtu_probing=1 >> /etc/sysctl.conf'
sudo sh -c 'echo net.core.default_qdisc = fq >> /etc/sysctl.conf'

sudo sysctl -p 

#
# Create Quagga and CorsaCRA instance

sudo yum update -y
sudo yum install -y yum-utils device-mapper-persistent-data lvm2

sudo yum-config-manager --add-repo https://download.docker.com/linux/centos/docker-ce.repo
sudo yum install -y docker-ce

sudo systemctl enable docker
sudo systemctl start docker
sudo systemctl status docker

yum install -y git
mkdir ~/corsa_cra
cd ~/corsa_cra/ 
git init 
git config core.sparsecheckout true 
echo corsa_cra/corsa_cra/* >> .git/info/sparse-checkout 
git remote add -f origin https://mcevik0@github.com/RENCI-NRIG/exogeni-recipes.git 
git pull origin master 


cd ~/corsa_cra/corsa_cra/corsa_cra/docker/

# Modify corsa_cra/quagga/bgpd.conf

sed -r -i \"s/<LOCAL_ASN>/${CHAMELEON_ASN}/g\" corsa_cra/quagga/bgpd.conf
sed -r -i \"s/<LOCAL_ROUTER_IP>/${CHAMELEON_ROUTER_IP_FACING_AWS}/g\" corsa_cra/quagga/bgpd.conf
sed -r -i \"s/<LOCAL_SUBNET>/${CHAMELEON_INTERNAL_SUBNET_ESC}/g\" corsa_cra/quagga/bgpd.conf
sed -r -i \"s/<REMOTE_ROUTER_IP>/${AWS_ROUTER_EXTERNAL_IP}/g\" corsa_cra/quagga/bgpd.conf
sed -r -i \"s/<REMOTE_ASN>/${AWS_ASN}/g\" corsa_cra/quagga/bgpd.conf
sed -r -i \"s/<REMOTE_DESC>/AWS/g\" corsa_cra/quagga/bgpd.conf
sed -r -i \"s/<BGP_PASSWORD>/${BGP_PASSWORD}/g\" corsa_cra/quagga/bgpd.conf

# Modify  corsa_cra/quagga/zebra.conf

sed -r -i \"s/<INTERFACE_FACING_AWS>/${IF_EXTERNAL_NET}/g\" corsa_cra/quagga/zebra.conf
sed -r -i \"s/<INTERFACE_FACING_LOCAL>/${IF_INTERNAL_NET}/g\" corsa_cra/quagga/zebra.conf
sed -r -i \"s/<IP_ADDRESS_FACING_AWS>/${CHAMELEON_ROUTER_IP_FACING_AWS_CIDR}/g\" corsa_cra/quagga/zebra.conf
sed -r -i \"s/<IP_ADDRESS_FACING_LOCAL>/${CHAMELEON_ROUTER_IP_FACING_INTERNAL_CIDR}/g\" corsa_cra/quagga/zebra.conf

cd ~/corsa_cra/corsa_cra/corsa_cra/docker/ 
sudo docker build -t cra_2 . 
sudo docker run --rm -dit --privileged --network host -p 6653:6653 --name=cra_2 cra_2 
sudo docker image ls

EOF"
# Out:
# Warning: Permanently added '192.5.87.172' (ECDSA) to the list of known hosts.
# Configure external iface
# net.core.rmem_max = 67108864
# net.core.wmem_max = 67108864
# net.ipv4.tcp_rmem = 4096 87380 33554432
# net.ipv4.tcp_wmem = 4096 65536 33554432
# net.ipv4.tcp_congestion_control = htcp
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq
# Loaded plugins: fastestmirror
# Loading mirror speeds from cached hostfile
#  * base: bay.uchicago.edu
#  * epel: ord.mirror.rackspace.com
#  * extras: mirror.mobap.edu
#  * updates: mirror.atlanticmetro.net
# Resolving Dependencies
# --> Running transaction check
# ---> Package python2-pip.noarch 0:8.1.2-12.el7 will be updated
# ---> Package python2-pip.noarch 0:8.1.2-14.el7 will be an update
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package              Arch            Version               Repository     Size
# ================================================================================
# Updating:
#  python2-pip          noarch          8.1.2-14.el7          epel          1.7 M
#
# Transaction Summary
# ================================================================================
# Upgrade  1 Package
#
# Total download size: 1.7 M
# Downloading packages:
# Delta RPMs disabled because /usr/bin/applydeltarpm not installed.
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
#   Updating   : python2-pip-8.1.2-14.el7.noarch                              1/2
#   Cleanup    : python2-pip-8.1.2-12.el7.noarch                              2/2
#   Verifying  : python2-pip-8.1.2-14.el7.noarch                              1/2
#   Verifying  : python2-pip-8.1.2-12.el7.noarch                              2/2
#
# Updated:
#   python2-pip.noarch 0:8.1.2-14.el7
#
# Complete!
# Loaded plugins: fastestmirror
# Loading mirror speeds from cached hostfile
#  * base: bay.uchicago.edu
#  * epel: mirror.steadfastnet.com
#  * extras: mirror.mobap.edu
#  * updates: mirror.steadfastnet.com
# Package yum-utils-1.1.31-54.el7_8.noarch already installed and latest version
# Package device-mapper-persistent-data-0.8.5-2.el7.x86_64 already installed and latest version
# Package 7:lvm2-2.02.186-7.el7_8.2.x86_64 already installed and latest version
# Nothing to do
# Loaded plugins: fastestmirror
# adding repo from: https://download.docker.com/linux/centos/docker-ce.repo
# grabbing file https://download.docker.com/linux/centos/docker-ce.repo to /etc/yum.repos.d/docker-ce.repo
# repo saved to /etc/yum.repos.d/docker-ce.repo
# Loaded plugins: fastestmirror
# Loading mirror speeds from cached hostfile
#  * base: bay.uchicago.edu
#  * epel: mirror.steadfastnet.com
#  * extras: mirror.mobap.edu
#  * updates: mirror.steadfastnet.com
# Resolving Dependencies
# --> Running transaction check
# ---> Package docker-ce.x86_64 3:19.03.13-3.el7 will be installed
# --> Processing Dependency: container-selinux >= 2:2.74 for package: 3:docker-ce-19.03.13-3.el7.x86_64
# --> Processing Dependency: containerd.io >= 1.2.2-3 for package: 3:docker-ce-19.03.13-3.el7.x86_64
# --> Processing Dependency: docker-ce-cli for package: 3:docker-ce-19.03.13-3.el7.x86_64
# --> Running transaction check
# ---> Package container-selinux.noarch 2:2.119.2-1.911c772.el7_8 will be installed
# ---> Package containerd.io.x86_64 0:1.3.7-3.1.el7 will be installed
# ---> Package docker-ce-cli.x86_64 1:19.03.13-3.el7 will be installed
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package            Arch    Version                     Repository         Size
# ================================================================================
# Installing:
#  docker-ce          x86_64  3:19.03.13-3.el7            docker-ce-stable   24 M
# Installing for dependencies:
#  container-selinux  noarch  2:2.119.2-1.911c772.el7_8   extras             40 k
#  containerd.io      x86_64  1.3.7-3.1.el7               docker-ce-stable   29 M
#  docker-ce-cli      x86_64  1:19.03.13-3.el7            docker-ce-stable   38 M
#
# Transaction Summary
# ================================================================================
# Install  1 Package (+3 Dependent packages)
#
# Total download size: 91 M
# Installed size: 385 M
# Downloading packages:
# Public key for docker-ce-19.03.13-3.el7.x86_64.rpm is not installed
# warning: /var/cache/yum/docker-ce-stable/packages/docker-ce-19.03.13-3.el7.x86_64.rpm: Header V4 RSA/SHA512 Signature, key ID 621e9f35: NOKEY
# --------------------------------------------------------------------------------
# Total                                              121 MB/s |  91 MB  00:00
# Retrieving key from https://download.docker.com/linux/centos/gpg
# Importing GPG key 0x621E9F35:
#  Userid     : "Docker Release (CE rpm) <docker@docker.com>"
#  Fingerprint: 060a 61c5 1b55 8a7f 742b 77aa c52f eb6b 621e 9f35
#  From       : https://download.docker.com/linux/centos/gpg
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
#   Installing : 2:container-selinux-2.119.2-1.911c772.el7_8.noarch           1/4
# setsebool:  SELinux is disabled.
#   Installing : containerd.io-1.3.7-3.1.el7.x86_64                           2/4
#   Installing : 1:docker-ce-cli-19.03.13-3.el7.x86_64                        3/4
#   Installing : 3:docker-ce-19.03.13-3.el7.x86_64                            4/4
#   Verifying  : containerd.io-1.3.7-3.1.el7.x86_64                           1/4
#   Verifying  : 2:container-selinux-2.119.2-1.911c772.el7_8.noarch           2/4
#   Verifying  : 1:docker-ce-cli-19.03.13-3.el7.x86_64                        3/4
#   Verifying  : 3:docker-ce-19.03.13-3.el7.x86_64                            4/4
#
# Installed:
#   docker-ce.x86_64 3:19.03.13-3.el7
#
# Dependency Installed:
#   container-selinux.noarch 2:2.119.2-1.911c772.el7_8
#   containerd.io.x86_64 0:1.3.7-3.1.el7
#   docker-ce-cli.x86_64 1:19.03.13-3.el7
#
# Complete!
# Created symlink from /etc/systemd/system/multi-user.target.wants/docker.service to /usr/lib/systemd/system/docker.service.
# ● docker.service - Docker Application Container Engine
#    Loaded: loaded (/usr/lib/systemd/system/docker.service; enabled; vendor preset: disabled)
#    Active: active (running) since Fri 2020-09-25 17:47:38 UTC; 14ms ago
#      Docs: https://docs.docker.com
#  Main PID: 10530 (dockerd)
#     Tasks: 34
#    Memory: 55.3M
#    CGroup: /system.slice/docker.service
#            └─10530 /usr/bin/dockerd -H fd:// --containerd=/run/containerd/containerd.sock
#
# Sep 25 17:47:28 pruth-aws-bgp-router.novalocal dockerd[10530]: time="2020-09-25T17:47:28.316331582Z" level=info msg="scheme \"unix\" not registered, fallback to default scheme" module=grpc
# Sep 25 17:47:28 pruth-aws-bgp-router.novalocal dockerd[10530]: time="2020-09-25T17:47:28.316349129Z" level=info msg="ccResolverWrapper: sending update to cc: {[{unix:///run/containerd/containerd.sock 0  <nil>}] <nil>}" module=grpc
# Sep 25 17:47:28 pruth-aws-bgp-router.novalocal dockerd[10530]: time="2020-09-25T17:47:28.316360180Z" level=info msg="ClientConn switching balancer to \"pick_first\"" module=grpc
# Sep 25 17:47:35 pruth-aws-bgp-router.novalocal dockerd[10530]: time="2020-09-25T17:47:35.251913227Z" level=info msg="Loading containers: start."
# Sep 25 17:47:38 pruth-aws-bgp-router.novalocal dockerd[10530]: time="2020-09-25T17:47:38.476000444Z" level=info msg="Default bridge (docker0) is assigned with an IP address 172.17.0.0/16. Daemon option --bip can be used to set a preferred IP address"
# Sep 25 17:47:38 pruth-aws-bgp-router.novalocal dockerd[10530]: time="2020-09-25T17:47:38.671615367Z" level=info msg="Loading containers: done."
# Sep 25 17:47:38 pruth-aws-bgp-router.novalocal dockerd[10530]: time="2020-09-25T17:47:38.708861766Z" level=info msg="Docker daemon" commit=4484c46d9d graphdriver(s)=overlay2 version=19.03.13
# Sep 25 17:47:38 pruth-aws-bgp-router.novalocal dockerd[10530]: time="2020-09-25T17:47:38.708949081Z" level=info msg="Daemon has completed initialization"
# Sep 25 17:47:38 pruth-aws-bgp-router.novalocal dockerd[10530]: time="2020-09-25T17:47:38.824407027Z" level=info msg="API listen on /var/run/docker.sock"
# Sep 25 17:47:38 pruth-aws-bgp-router.novalocal systemd[1]: Started Docker Application Container Engine.
# Loaded plugins: fastestmirror
# You need to be root to perform this command.
# Initialized empty Git repository in /home/cc/corsa_cra/.git/
# Updating origin
# From https://github.com/RENCI-NRIG/exogeni-recipes
#  * [new branch]      1_ssl_for_elastic -> origin/1_ssl_for_elastic
#  * [new branch]      hadoop-kerberos -> origin/hadoop-kerberos
#  * [new branch]      master     -> origin/master
# From https://github.com/RENCI-NRIG/exogeni-recipes
#  * branch            master     -> FETCH_HEAD
# Sending build context to Docker daemon  1.473MB
# Step 1/37 : FROM ubuntu:14.04
# 14.04: Pulling from library/ubuntu
# 2e6e20c8e2e6: Pulling fs layer
# 95201152d9ff: Pulling fs layer
# 5f63a3b65493: Pulling fs layer
# 95201152d9ff: Download complete
# 5f63a3b65493: Verifying Checksum
# 5f63a3b65493: Download complete
# 2e6e20c8e2e6: Verifying Checksum
# 2e6e20c8e2e6: Download complete
# 2e6e20c8e2e6: Pull complete
# 95201152d9ff: Pull complete
# 5f63a3b65493: Pull complete
# Digest: sha256:63fce984528cec8714c365919882f8fb64c8a3edf23fdfa0b218a2756125456f
# Status: Downloaded newer image for ubuntu:14.04
#  ---> df043b4f0cf1
# Step 2/37 : ENV DEBIAN_FRONTEND noninteractive
#  ---> Running in 67ec0b0f0282
# Removing intermediate container 67ec0b0f0282
#  ---> 65713ce33209
# Step 3/37 : RUN apt-get update && apt-get -y upgrade
#  ---> Running in dc1b11c03f8b
# Get:1 http://security.ubuntu.com trusty-security InRelease [65.9 kB]
# Get:2 http://security.ubuntu.com trusty-security/main amd64 Packages [1032 kB]
# Ign http://archive.ubuntu.com trusty InRelease
# Get:3 http://security.ubuntu.com trusty-security/restricted amd64 Packages [18.1 kB]
# Get:4 http://archive.ubuntu.com trusty-updates InRelease [65.9 kB]
# Get:5 http://security.ubuntu.com trusty-security/universe amd64 Packages [378 kB]
# Get:6 http://security.ubuntu.com trusty-security/multiverse amd64 Packages [4730 B]
# Get:7 https://esm.ubuntu.com trusty-infra-security InRelease
# Get:8 http://archive.ubuntu.com trusty-backports InRelease [65.9 kB]
# Get:9 https://esm.ubuntu.com trusty-infra-updates InRelease
# Hit http://archive.ubuntu.com trusty Release.gpg
# Get:10 https://esm.ubuntu.com trusty-infra-security/main amd64 Packages
# Get:11 http://archive.ubuntu.com trusty-updates/main amd64 Packages [1460 kB]
# Get:12 https://esm.ubuntu.com trusty-infra-updates/main amd64 Packages
# Get:13 http://archive.ubuntu.com trusty-updates/restricted amd64 Packages [21.4 kB]
# Get:14 http://archive.ubuntu.com trusty-updates/universe amd64 Packages [671 kB]
# Get:15 http://archive.ubuntu.com trusty-updates/multiverse amd64 Packages [16.1 kB]
# Get:16 http://archive.ubuntu.com trusty-backports/main amd64 Packages [14.7 kB]
# Get:17 http://archive.ubuntu.com trusty-backports/restricted amd64 Packages [40 B]
# Get:18 http://archive.ubuntu.com trusty-backports/universe amd64 Packages [52.5 kB]
# Get:19 http://archive.ubuntu.com trusty-backports/multiverse amd64 Packages [1392 B]
# Hit http://archive.ubuntu.com trusty Release
# Get:20 http://archive.ubuntu.com trusty/main amd64 Packages [1743 kB]
# Get:21 http://archive.ubuntu.com trusty/restricted amd64 Packages [16.0 kB]
# Get:22 http://archive.ubuntu.com trusty/universe amd64 Packages [7589 kB]
# Get:23 http://archive.ubuntu.com trusty/multiverse amd64 Packages [169 kB]
# Fetched 13.8 MB in 4s (3416 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following packages will be upgraded:
#   ubuntu-advantage-tools
# 1 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# Need to get 47.3 kB of archives.
# After this operation, 1024 B of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu/ trusty-updates/main ubuntu-advantage-tools amd64 19.6~ubuntu14.04.4 [47.3 kB]
# Fetched 47.3 kB in 0s (133 kB/s)
# (Reading database ... 12097 files and directories currently installed.)
# Preparing to unpack .../ubuntu-advantage-tools_19.6~ubuntu14.04.4_amd64.deb ...
# Unpacking ubuntu-advantage-tools (19.6~ubuntu14.04.4) over (19.6~ubuntu14.04.3) ...
# Setting up ubuntu-advantage-tools (19.6~ubuntu14.04.4) ...
# Removing intermediate container dc1b11c03f8b
#  ---> ba01896bd580
# Step 4/37 : RUN echo exit 0 > /usr/sbin/policy-rc.d
#  ---> Running in e620b0596b2a
# Removing intermediate container e620b0596b2a
#  ---> 7771cab23ad5
# Step 5/37 : RUN apt-get install -y telnet  && apt-get install -y vim  && apt-get install -y libzmq1  && apt-get install -y libevent-2.0-5  && apt-get install -y libevent-openssl-2.0-5  && apt-get install -y libevent-core-2.0-5  && apt-get install -y libevent-pthreads-2.0-5  && apt-get install -y libyaml-0-2  && apt-get install -y libjsoncpp0  && apt-get install -y libprotobuf8  && apt-get install -y arping  && apt-get install -y ndisc6  && apt-get install -y libboost-filesystem1.54.0  && apt-get install -y libboost-iostreams1.54.0  && apt-get install -y libboost-log1.54.0  && apt-get install -y libboost-system1.54.0  && apt-get install -y libboost-thread1.54.0
#  ---> Running in 9cbe4a96f84e
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   telnet
# 0 upgraded, 1 newly installed, 0 to remove and 0 not upgraded.
# Need to get 67.1 kB of archives.
# After this operation, 167 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu/ trusty/main telnet amd64 0.17-36build2 [67.1 kB]
# Fetched 67.1 kB in 0s (187 kB/s)
# Selecting previously unselected package telnet.
# (Reading database ... 12097 files and directories currently installed.)
# Preparing to unpack .../telnet_0.17-36build2_amd64.deb ...
# Unpacking telnet (0.17-36build2) ...
# Setting up telnet (0.17-36build2) ...
# update-alternatives: using /usr/bin/telnet.netkit to provide /usr/bin/telnet (telnet) in auto mode
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following extra packages will be installed:
#   libgpm2 libpython2.7 libpython2.7-minimal libpython2.7-stdlib vim-runtime
# Suggested packages:
#   gpm ctags vim-doc vim-scripts
# The following NEW packages will be installed:
#   libgpm2 libpython2.7 libpython2.7-minimal libpython2.7-stdlib vim
#   vim-runtime
# 0 upgraded, 6 newly installed, 0 to remove and 0 not upgraded.
# Need to get 9076 kB of archives.
# After this operation, 42.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu/ trusty/main libgpm2 amd64 1.20.4-6.1 [16.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libpython2.7-minimal amd64 2.7.6-8ubuntu0.5 [308 kB]
# Get:3 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libpython2.7-stdlib amd64 2.7.6-8ubuntu0.5 [1872 kB]
# Get:4 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libpython2.7 amd64 2.7.6-8ubuntu0.5 [1041 kB]
# Get:5 http://archive.ubuntu.com/ubuntu/ trusty-updates/main vim-runtime all 2:7.4.052-1ubuntu3.1 [4882 kB]
# Get:6 http://archive.ubuntu.com/ubuntu/ trusty-updates/main vim amd64 2:7.4.052-1ubuntu3.1 [955 kB]
# Fetched 9076 kB in 1s (5793 kB/s)
# Selecting previously unselected package libgpm2:amd64.
# (Reading database ... 12107 files and directories currently installed.)
# Preparing to unpack .../libgpm2_1.20.4-6.1_amd64.deb ...
# Unpacking libgpm2:amd64 (1.20.4-6.1) ...
# Selecting previously unselected package libpython2.7-minimal:amd64.
# Preparing to unpack .../libpython2.7-minimal_2.7.6-8ubuntu0.5_amd64.deb ...
# Unpacking libpython2.7-minimal:amd64 (2.7.6-8ubuntu0.5) ...
# Selecting previously unselected package libpython2.7-stdlib:amd64.
# Preparing to unpack .../libpython2.7-stdlib_2.7.6-8ubuntu0.5_amd64.deb ...
# Unpacking libpython2.7-stdlib:amd64 (2.7.6-8ubuntu0.5) ...
# Selecting previously unselected package libpython2.7:amd64.
# Preparing to unpack .../libpython2.7_2.7.6-8ubuntu0.5_amd64.deb ...
# Unpacking libpython2.7:amd64 (2.7.6-8ubuntu0.5) ...
# Selecting previously unselected package vim-runtime.
# Preparing to unpack .../vim-runtime_2%3a7.4.052-1ubuntu3.1_all.deb ...
# Adding 'diversion of /usr/share/vim/vim74/doc/help.txt to /usr/share/vim/vim74/doc/help.txt.vim-tiny by vim-runtime'
# Adding 'diversion of /usr/share/vim/vim74/doc/tags to /usr/share/vim/vim74/doc/tags.vim-tiny by vim-runtime'
# Unpacking vim-runtime (2:7.4.052-1ubuntu3.1) ...
# Selecting previously unselected package vim.
# Preparing to unpack .../vim_2%3a7.4.052-1ubuntu3.1_amd64.deb ...
# Unpacking vim (2:7.4.052-1ubuntu3.1) ...
# Setting up libgpm2:amd64 (1.20.4-6.1) ...
# Setting up libpython2.7-minimal:amd64 (2.7.6-8ubuntu0.5) ...
# Setting up libpython2.7-stdlib:amd64 (2.7.6-8ubuntu0.5) ...
# Setting up libpython2.7:amd64 (2.7.6-8ubuntu0.5) ...
# Setting up vim-runtime (2:7.4.052-1ubuntu3.1) ...
# Processing /usr/share/vim/addons/doc
# Setting up vim (2:7.4.052-1ubuntu3.1) ...
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/vim (vim) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/vimdiff (vimdiff) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/rvim (rvim) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/rview (rview) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/vi (vi) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/view (view) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/ex (ex) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/editor (editor) in auto mode
# Processing triggers for libc-bin (2.19-0ubuntu6.15) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following extra packages will be installed:
#   libpgm-5.1-0
# The following NEW packages will be installed:
#   libpgm-5.1-0 libzmq1
# 0 upgraded, 2 newly installed, 0 to remove and 0 not upgraded.
# Need to get 245 kB of archives.
# After this operation, 627 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu/ trusty/universe libpgm-5.1-0 amd64 5.1.118-1~dfsg-0.1ubuntu3 [156 kB]
# Get:2 http://archive.ubuntu.com/ubuntu/ trusty/universe libzmq1 amd64 2.2.0+dfsg-5 [89.1 kB]
# Fetched 245 kB in 0s (378 kB/s)
# Selecting previously unselected package libpgm-5.1-0:amd64.
# (Reading database ... 14429 files and directories currently installed.)
# Preparing to unpack .../libpgm-5.1-0_5.1.118-1~dfsg-0.1ubuntu3_amd64.deb ...
# Unpacking libpgm-5.1-0:amd64 (5.1.118-1~dfsg-0.1ubuntu3) ...
# Selecting previously unselected package libzmq1:amd64.
# Preparing to unpack .../libzmq1_2.2.0+dfsg-5_amd64.deb ...
# Unpacking libzmq1:amd64 (2.2.0+dfsg-5) ...
# Setting up libpgm-5.1-0:amd64 (5.1.118-1~dfsg-0.1ubuntu3) ...
# Setting up libzmq1:amd64 (2.2.0+dfsg-5) ...
# Processing triggers for libc-bin (2.19-0ubuntu6.15) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   libevent-2.0-5
# 0 upgraded, 1 newly installed, 0 to remove and 0 not upgraded.
# Need to get 126 kB of archives.
# After this operation, 318 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libevent-2.0-5 amd64 2.0.21-stable-1ubuntu1.14.04.2 [126 kB]
# Fetched 126 kB in 0s (274 kB/s)
# Selecting previously unselected package libevent-2.0-5:amd64.
# (Reading database ... 14442 files and directories currently installed.)
# Preparing to unpack .../libevent-2.0-5_2.0.21-stable-1ubuntu1.14.04.2_amd64.deb ...
# Unpacking libevent-2.0-5:amd64 (2.0.21-stable-1ubuntu1.14.04.2) ...
# Setting up libevent-2.0-5:amd64 (2.0.21-stable-1ubuntu1.14.04.2) ...
# Processing triggers for libc-bin (2.19-0ubuntu6.15) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following extra packages will be installed:
#   libevent-core-2.0-5
# The following NEW packages will be installed:
#   libevent-core-2.0-5 libevent-openssl-2.0-5
# 0 upgraded, 2 newly installed, 0 to remove and 0 not upgraded.
# Need to get 91.1 kB of archives.
# After this operation, 272 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libevent-core-2.0-5 amd64 2.0.21-stable-1ubuntu1.14.04.2 [78.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libevent-openssl-2.0-5 amd64 2.0.21-stable-1ubuntu1.14.04.2 [12.7 kB]
# Fetched 91.1 kB in 0s (187 kB/s)
# Selecting previously unselected package libevent-core-2.0-5:amd64.
# (Reading database ... 14447 files and directories currently installed.)
# Preparing to unpack .../libevent-core-2.0-5_2.0.21-stable-1ubuntu1.14.04.2_amd64.deb ...
# Unpacking libevent-core-2.0-5:amd64 (2.0.21-stable-1ubuntu1.14.04.2) ...
# Selecting previously unselected package libevent-openssl-2.0-5:amd64.
# Preparing to unpack .../libevent-openssl-2.0-5_2.0.21-stable-1ubuntu1.14.04.2_amd64.deb ...
# Unpacking libevent-openssl-2.0-5:amd64 (2.0.21-stable-1ubuntu1.14.04.2) ...
# Setting up libevent-core-2.0-5:amd64 (2.0.21-stable-1ubuntu1.14.04.2) ...
# Setting up libevent-openssl-2.0-5:amd64 (2.0.21-stable-1ubuntu1.14.04.2) ...
# Processing triggers for libc-bin (2.19-0ubuntu6.15) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# libevent-core-2.0-5 is already the newest version.
# libevent-core-2.0-5 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   libevent-pthreads-2.0-5
# 0 upgraded, 1 newly installed, 0 to remove and 0 not upgraded.
# Need to get 6098 B of archives.
# After this operation, 51.2 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libevent-pthreads-2.0-5 amd64 2.0.21-stable-1ubuntu1.14.04.2 [6098 B]
# Fetched 6098 B in 0s (33.8 kB/s)
# Selecting previously unselected package libevent-pthreads-2.0-5:amd64.
# (Reading database ... 14457 files and directories currently installed.)
# Preparing to unpack .../libevent-pthreads-2.0-5_2.0.21-stable-1ubuntu1.14.04.2_amd64.deb ...
# Unpacking libevent-pthreads-2.0-5:amd64 (2.0.21-stable-1ubuntu1.14.04.2) ...
# Setting up libevent-pthreads-2.0-5:amd64 (2.0.21-stable-1ubuntu1.14.04.2) ...
# Processing triggers for libc-bin (2.19-0ubuntu6.15) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# libyaml-0-2 is already the newest version.
# libyaml-0-2 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   libjsoncpp0
# 0 upgraded, 1 newly installed, 0 to remove and 0 not upgraded.
# Need to get 56.5 kB of archives.
# After this operation, 189 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu/ trusty/universe libjsoncpp0 amd64 0.6.0~rc2-3ubuntu1 [56.5 kB]
# Fetched 56.5 kB in 0s (153 kB/s)
# Selecting previously unselected package libjsoncpp0:amd64.
# (Reading database ... 14462 files and directories currently installed.)
# Preparing to unpack .../libjsoncpp0_0.6.0~rc2-3ubuntu1_amd64.deb ...
# Unpacking libjsoncpp0:amd64 (0.6.0~rc2-3ubuntu1) ...
# Setting up libjsoncpp0:amd64 (0.6.0~rc2-3ubuntu1) ...
# Processing triggers for libc-bin (2.19-0ubuntu6.15) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   libprotobuf8
# 0 upgraded, 1 newly installed, 0 to remove and 0 not upgraded.
# Need to get 296 kB of archives.
# After this operation, 1109 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu/ trusty/main libprotobuf8 amd64 2.5.0-9ubuntu1 [296 kB]
# Fetched 296 kB in 0s (503 kB/s)
# Selecting previously unselected package libprotobuf8:amd64.
# (Reading database ... 14471 files and directories currently installed.)
# Preparing to unpack .../libprotobuf8_2.5.0-9ubuntu1_amd64.deb ...
# Unpacking libprotobuf8:amd64 (2.5.0-9ubuntu1) ...
# Setting up libprotobuf8:amd64 (2.5.0-9ubuntu1) ...
# Processing triggers for libc-bin (2.19-0ubuntu6.15) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following extra packages will be installed:
#   libnet1 libpcap0.8
# The following NEW packages will be installed:
#   arping libnet1 libpcap0.8
# 0 upgraded, 3 newly installed, 0 to remove and 0 not upgraded.
# Need to get 177 kB of archives.
# After this operation, 571 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu/ trusty/main libpcap0.8 amd64 1.5.3-2 [110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu/ trusty/main libnet1 amd64 1.1.6+dfsg-2ubuntu1 [41.8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu/ trusty/universe arping amd64 2.11-1 [25.3 kB]
# Fetched 177 kB in 0s (268 kB/s)
# Selecting previously unselected package libpcap0.8:amd64.
# (Reading database ... 14476 files and directories currently installed.)
# Preparing to unpack .../libpcap0.8_1.5.3-2_amd64.deb ...
# Unpacking libpcap0.8:amd64 (1.5.3-2) ...
# Selecting previously unselected package libnet1:amd64.
# Preparing to unpack .../libnet1_1.1.6+dfsg-2ubuntu1_amd64.deb ...
# Unpacking libnet1:amd64 (1.1.6+dfsg-2ubuntu1) ...
# Selecting previously unselected package arping.
# Preparing to unpack .../arping_2.11-1_amd64.deb ...
# Unpacking arping (2.11-1) ...
# Setting up libpcap0.8:amd64 (1.5.3-2) ...
# Setting up libnet1:amd64 (1.1.6+dfsg-2ubuntu1) ...
# Setting up arping (2.11-1) ...
# Processing triggers for libc-bin (2.19-0ubuntu6.15) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   ndisc6
# 0 upgraded, 1 newly installed, 0 to remove and 0 not upgraded.
# Need to get 66.6 kB of archives.
# After this operation, 369 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu/ trusty/universe ndisc6 amd64 1.0.1-1ubuntu1 [66.6 kB]
# Fetched 66.6 kB in 0s (169 kB/s)
# Selecting previously unselected package ndisc6.
# (Reading database ... 14504 files and directories currently installed.)
# Preparing to unpack .../ndisc6_1.0.1-1ubuntu1_amd64.deb ...
# Unpacking ndisc6 (1.0.1-1ubuntu1) ...
# Setting up ndisc6 (1.0.1-1ubuntu1) ...
# update-alternatives: using /usr/bin/rltraceroute6 to provide /usr/bin/traceroute6 (traceroute6) in auto mode
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following extra packages will be installed:
#   libboost-system1.54.0
# The following NEW packages will be installed:
#   libboost-filesystem1.54.0 libboost-system1.54.0
# 0 upgraded, 2 newly installed, 0 to remove and 0 not upgraded.
# Need to get 44.4 kB of archives.
# After this operation, 243 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libboost-system1.54.0 amd64 1.54.0-4ubuntu3.1 [10.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libboost-filesystem1.54.0 amd64 1.54.0-4ubuntu3.1 [34.2 kB]
# Fetched 44.4 kB in 0s (121 kB/s)
# Selecting previously unselected package libboost-system1.54.0:amd64.
# (Reading database ... 14537 files and directories currently installed.)
# Preparing to unpack .../libboost-system1.54.0_1.54.0-4ubuntu3.1_amd64.deb ...
# Unpacking libboost-system1.54.0:amd64 (1.54.0-4ubuntu3.1) ...
# Selecting previously unselected package libboost-filesystem1.54.0:amd64.
# Preparing to unpack .../libboost-filesystem1.54.0_1.54.0-4ubuntu3.1_amd64.deb ...
# Unpacking libboost-filesystem1.54.0:amd64 (1.54.0-4ubuntu3.1) ...
# Setting up libboost-system1.54.0:amd64 (1.54.0-4ubuntu3.1) ...
# Setting up libboost-filesystem1.54.0:amd64 (1.54.0-4ubuntu3.1) ...
# Processing triggers for libc-bin (2.19-0ubuntu6.15) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   libboost-iostreams1.54.0
# 0 upgraded, 1 newly installed, 0 to remove and 0 not upgraded.
# Need to get 29.0 kB of archives.
# After this operation, 171 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libboost-iostreams1.54.0 amd64 1.54.0-4ubuntu3.1 [29.0 kB]
# Fetched 29.0 kB in 0s (108 kB/s)
# Selecting previously unselected package libboost-iostreams1.54.0:amd64.
# (Reading database ... 14547 files and directories currently installed.)
# Preparing to unpack .../libboost-iostreams1.54.0_1.54.0-4ubuntu3.1_amd64.deb ...
# Unpacking libboost-iostreams1.54.0:amd64 (1.54.0-4ubuntu3.1) ...
# Setting up libboost-iostreams1.54.0:amd64 (1.54.0-4ubuntu3.1) ...
# Processing triggers for libc-bin (2.19-0ubuntu6.15) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following extra packages will be installed:
#   libboost-thread1.54.0
# The following NEW packages will be installed:
#   libboost-log1.54.0 libboost-thread1.54.0
# 0 upgraded, 2 newly installed, 0 to remove and 0 not upgraded.
# Need to get 556 kB of archives.
# After this operation, 3106 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libboost-thread1.54.0 amd64 1.54.0-4ubuntu3.1 [26.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu/ trusty-updates/universe libboost-log1.54.0 amd64 1.54.0-4ubuntu3.1 [529 kB]
# Fetched 556 kB in 0s (741 kB/s)
# Selecting previously unselected package libboost-thread1.54.0:amd64.
# (Reading database ... 14552 files and directories currently installed.)
# Preparing to unpack .../libboost-thread1.54.0_1.54.0-4ubuntu3.1_amd64.deb ...
# Unpacking libboost-thread1.54.0:amd64 (1.54.0-4ubuntu3.1) ...
# Selecting previously unselected package libboost-log1.54.0.
# Preparing to unpack .../libboost-log1.54.0_1.54.0-4ubuntu3.1_amd64.deb ...
# Unpacking libboost-log1.54.0 (1.54.0-4ubuntu3.1) ...
# Setting up libboost-thread1.54.0:amd64 (1.54.0-4ubuntu3.1) ...
# Setting up libboost-log1.54.0 (1.54.0-4ubuntu3.1) ...
# Processing triggers for libc-bin (2.19-0ubuntu6.15) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# libboost-system1.54.0 is already the newest version.
# libboost-system1.54.0 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# libboost-thread1.54.0 is already the newest version.
# libboost-thread1.54.0 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# Removing intermediate container 9cbe4a96f84e
#  ---> 3c1492ad5486
# Step 6/37 : RUN apt-get install -y  git wget gawk  texinfo libreadline-dev  build-essential
#  ---> Running in 6d5411d5533e
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following extra packages will be installed:
#   binutils cpp cpp-4.8 dpkg-dev fakeroot g++ g++-4.8 gcc gcc-4.8 git-man
#   libalgorithm-diff-perl libalgorithm-diff-xs-perl libalgorithm-merge-perl
#   libasan0 libatomic1 libauthen-sasl-perl libc-dev-bin libc6-dev libcloog-isl4
#   libdpkg-perl libedit2 libencode-locale-perl liberror-perl libfakeroot
#   libfile-fcntllock-perl libfile-listing-perl libfont-afm-perl libgcc-4.8-dev
#   libgmp10 libgomp1 libhtml-form-perl libhtml-format-perl libhtml-parser-perl
#   libhtml-tagset-perl libhtml-tree-perl libhttp-cookies-perl
#   libhttp-daemon-perl libhttp-date-perl libhttp-message-perl
#   libhttp-negotiate-perl libintl-perl libio-html-perl libio-socket-inet6-perl
#   libio-socket-ssl-perl libisl10 libitm1 liblwp-mediatypes-perl
#   liblwp-protocol-https-perl libmailtools-perl libmpc3 libmpfr4
#   libnet-http-perl libnet-smtp-ssl-perl libnet-ssleay-perl libquadmath0
#   libreadline6-dev libsigsegv2 libsocket6-perl libstdc++-4.8-dev
#   libtext-unidecode-perl libtimedate-perl libtinfo-dev libtsan0 liburi-perl
#   libwww-perl libwww-robotrules-perl libx11-6 libx11-data libxau6 libxcb1
#   libxdmcp6 libxext6 libxml-libxml-perl libxml-namespacesupport-perl
#   libxml-parser-perl libxml-sax-base-perl libxml-sax-expat-perl
#   libxml-sax-perl libxml2 libxmuu1 linux-libc-dev make manpages manpages-dev
#   openssh-client patch rsync sgml-base xauth xml-core xz-utils
# Suggested packages:
#   binutils-doc cpp-doc gcc-4.8-locales debian-keyring g++-multilib
#   g++-4.8-multilib gcc-4.8-doc libstdc++6-4.8-dbg gawk-doc gcc-multilib
#   autoconf automake1.9 libtool flex bison gdb gcc-doc gcc-4.8-multilib
#   libgcc1-dbg libgomp1-dbg libitm1-dbg libatomic1-dbg libasan0-dbg
#   libtsan0-dbg libquadmath0-dbg gettext-base git-daemon-run
#   git-daemon-sysvinit git-doc git-el git-email git-gui gitk gitweb git-arch
#   git-bzr git-cvs git-mediawiki git-svn libdigest-hmac-perl libgssapi-perl
#   glibc-doc libdata-dump-perl libintl-xs-perl libcrypt-ssleay-perl
#   libstdc++-4.8-doc libauthen-ntlm-perl make-doc man-browser ssh-askpass
#   libpam-ssh keychain monkeysphere ed diffutils-doc openssh-server
#   sgml-base-doc texlive-base texlive-latex-base texlive-generic-recommended
#   texinfo-doc-nonfree debhelper
# Recommended packages:
#   ssh-client
# The following NEW packages will be installed:
#   binutils build-essential cpp cpp-4.8 dpkg-dev fakeroot g++ g++-4.8 gawk gcc
#   gcc-4.8 git git-man libalgorithm-diff-perl libalgorithm-diff-xs-perl
#   libalgorithm-merge-perl libasan0 libatomic1 libauthen-sasl-perl libc-dev-bin
#   libc6-dev libcloog-isl4 libdpkg-perl libedit2 libencode-locale-perl
#   liberror-perl libfakeroot libfile-fcntllock-perl libfile-listing-perl
#   libfont-afm-perl libgcc-4.8-dev libgmp10 libgomp1 libhtml-form-perl
#   libhtml-format-perl libhtml-parser-perl libhtml-tagset-perl
#   libhtml-tree-perl libhttp-cookies-perl libhttp-daemon-perl libhttp-date-perl
#   libhttp-message-perl libhttp-negotiate-perl libintl-perl libio-html-perl
#   libio-socket-inet6-perl libio-socket-ssl-perl libisl10 libitm1
#   liblwp-mediatypes-perl liblwp-protocol-https-perl libmailtools-perl libmpc3
#   libmpfr4 libnet-http-perl libnet-smtp-ssl-perl libnet-ssleay-perl
#   libquadmath0 libreadline-dev libreadline6-dev libsigsegv2 libsocket6-perl
#   libstdc++-4.8-dev libtext-unidecode-perl libtimedate-perl libtinfo-dev
#   libtsan0 liburi-perl libwww-perl libwww-robotrules-perl libx11-6 libx11-data
#   libxau6 libxcb1 libxdmcp6 libxext6 libxml-libxml-perl
#   libxml-namespacesupport-perl libxml-parser-perl libxml-sax-base-perl
#   libxml-sax-expat-perl libxml-sax-perl libxml2 libxmuu1 linux-libc-dev make
#   manpages manpages-dev openssh-client patch rsync sgml-base texinfo wget
#   xauth xml-core xz-utils
# 0 upgraded, 97 newly installed, 0 to remove and 0 not upgraded.
# Need to get 51.4 MB of archives.
# After this operation, 168 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu/ trusty/main libedit2 amd64 3.1-20130712-2 [86.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu/ trusty/main libxau6 amd64 1:1.0.8-1 [8376 B]
# Get:3 http://archive.ubuntu.com/ubuntu/ trusty/main libxdmcp6 amd64 1:1.1.1-1 [12.8 kB]
# Get:4 http://archive.ubuntu.com/ubuntu/ trusty/main libxcb1 amd64 1.10-2ubuntu1 [38.0 kB]
# Get:5 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libx11-data all 2:1.6.2-1ubuntu2.1 [111 kB]
# Get:6 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libx11-6 amd64 2:1.6.2-1ubuntu2.1 [561 kB]
# Get:7 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libxext6 amd64 2:1.3.2-1ubuntu0.0.14.04.1 [28.8 kB]
# Get:8 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libxml2 amd64 2.9.1+dfsg1-3ubuntu4.13 [573 kB]
# Get:9 http://archive.ubuntu.com/ubuntu/ trusty/main libxmuu1 amd64 2:1.1.1-1 [11.0 kB]
# Get:10 http://archive.ubuntu.com/ubuntu/ trusty/main sgml-base all 1.26+nmu4ubuntu1 [12.5 kB]
# Get:11 http://archive.ubuntu.com/ubuntu/ trusty/main libsigsegv2 amd64 2.10-2 [15.0 kB]
# Get:12 http://archive.ubuntu.com/ubuntu/ trusty/main gawk amd64 1:4.0.1+dfsg-2.1ubuntu2 [781 kB]
# Get:13 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libasan0 amd64 4.8.4-2ubuntu1~14.04.4 [63.1 kB]
# Get:14 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libatomic1 amd64 4.8.4-2ubuntu1~14.04.4 [8630 B]
# Get:15 http://archive.ubuntu.com/ubuntu/ trusty/main libgmp10 amd64 2:5.1.3+dfsg-1ubuntu1 [218 kB]
# Get:16 http://archive.ubuntu.com/ubuntu/ trusty/main libisl10 amd64 0.12.2-1 [419 kB]
# Get:17 http://archive.ubuntu.com/ubuntu/ trusty/main libcloog-isl4 amd64 0.18.2-1 [57.5 kB]
# Get:18 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libgomp1 amd64 4.8.4-2ubuntu1~14.04.4 [23.1 kB]
# Get:19 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libitm1 amd64 4.8.4-2ubuntu1~14.04.4 [28.6 kB]
# Get:20 http://archive.ubuntu.com/ubuntu/ trusty/main libmpfr4 amd64 3.1.2-1 [203 kB]
# Get:21 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libquadmath0 amd64 4.8.4-2ubuntu1~14.04.4 [126 kB]
# Get:22 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libtsan0 amd64 4.8.4-2ubuntu1~14.04.4 [94.8 kB]
# Get:23 http://archive.ubuntu.com/ubuntu/ trusty/main libmpc3 amd64 1.0.1-1ubuntu1 [38.4 kB]
# Get:24 http://archive.ubuntu.com/ubuntu/ trusty/main manpages all 3.54-1ubuntu1 [627 kB]
# Get:25 http://archive.ubuntu.com/ubuntu/ trusty-updates/main openssh-client amd64 1:6.6p1-2ubuntu2.13 [567 kB]
# Get:26 http://archive.ubuntu.com/ubuntu/ trusty-updates/main rsync amd64 3.1.0-2ubuntu0.4 [284 kB]
# Get:27 http://archive.ubuntu.com/ubuntu/ trusty-updates/main wget amd64 1.15-1ubuntu1.14.04.5 [270 kB]
# Get:28 http://archive.ubuntu.com/ubuntu/ trusty/main xauth amd64 1:1.0.7-1ubuntu1 [25.8 kB]
# Get:29 http://archive.ubuntu.com/ubuntu/ trusty/main xml-core all 0.13+nmu2 [23.3 kB]
# Get:30 http://archive.ubuntu.com/ubuntu/ trusty-updates/main binutils amd64 2.24-5ubuntu14.2 [2076 kB]
# Get:31 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libc-dev-bin amd64 2.19-0ubuntu6.15 [68.9 kB]
# Get:32 http://archive.ubuntu.com/ubuntu/ trusty-updates/main linux-libc-dev amd64 3.13.0-170.220 [772 kB]
# Get:33 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libc6-dev amd64 2.19-0ubuntu6.15 [1913 kB]
# Get:34 http://archive.ubuntu.com/ubuntu/ trusty-updates/main cpp-4.8 amd64 4.8.4-2ubuntu1~14.04.4 [4452 kB]
# Get:35 http://archive.ubuntu.com/ubuntu/ trusty/main cpp amd64 4:4.8.2-1ubuntu6 [27.5 kB]
# Get:36 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libgcc-4.8-dev amd64 4.8.4-2ubuntu1~14.04.4 [1688 kB]
# Get:37 http://archive.ubuntu.com/ubuntu/ trusty-updates/main gcc-4.8 amd64 4.8.4-2ubuntu1~14.04.4 [5040 kB]
# Get:38 http://archive.ubuntu.com/ubuntu/ trusty/main gcc amd64 4:4.8.2-1ubuntu6 [5098 B]
# Get:39 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libstdc++-4.8-dev amd64 4.8.4-2ubuntu1~14.04.4 [1051 kB]
# Get:40 http://archive.ubuntu.com/ubuntu/ trusty-updates/main g++-4.8 amd64 4.8.4-2ubuntu1~14.04.4 [18.0 MB]
# Get:41 http://archive.ubuntu.com/ubuntu/ trusty/main g++ amd64 4:4.8.2-1ubuntu6 [1490 B]
# Get:42 http://archive.ubuntu.com/ubuntu/ trusty/main make amd64 3.81-8.2ubuntu3 [119 kB]
# Get:43 http://archive.ubuntu.com/ubuntu/ trusty/main libtimedate-perl all 2.3000-1 [37.2 kB]
# Get:44 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libdpkg-perl all 1.17.5ubuntu5.8 [179 kB]
# Get:45 http://archive.ubuntu.com/ubuntu/ trusty/main xz-utils amd64 5.1.1alpha+20120614-2ubuntu2 [78.8 kB]
# Get:46 http://archive.ubuntu.com/ubuntu/ trusty-updates/main patch amd64 2.7.1-4ubuntu2.4 [86.9 kB]
# Get:47 http://archive.ubuntu.com/ubuntu/ trusty-updates/main dpkg-dev all 1.17.5ubuntu5.8 [726 kB]
# Get:48 http://archive.ubuntu.com/ubuntu/ trusty/main build-essential amd64 11.6ubuntu6 [4838 B]
# Get:49 http://archive.ubuntu.com/ubuntu/ trusty/main libfakeroot amd64 1.20-3ubuntu2 [25.4 kB]
# Get:50 http://archive.ubuntu.com/ubuntu/ trusty/main fakeroot amd64 1.20-3ubuntu2 [55.0 kB]
# Get:51 http://archive.ubuntu.com/ubuntu/ trusty/main liberror-perl all 0.17-1.1 [21.1 kB]
# Get:52 http://archive.ubuntu.com/ubuntu/ trusty-updates/main git-man all 1:1.9.1-1ubuntu0.10 [700 kB]
# Get:53 http://archive.ubuntu.com/ubuntu/ trusty-updates/main git amd64 1:1.9.1-1ubuntu0.10 [2737 kB]
# Get:54 http://archive.ubuntu.com/ubuntu/ trusty/main libalgorithm-diff-perl all 1.19.02-3 [50.0 kB]
# Get:55 http://archive.ubuntu.com/ubuntu/ trusty/main libalgorithm-diff-xs-perl amd64 0.04-2build4 [12.6 kB]
# Get:56 http://archive.ubuntu.com/ubuntu/ trusty/main libalgorithm-merge-perl all 0.08-2 [12.7 kB]
# Get:57 http://archive.ubuntu.com/ubuntu/ trusty/main libencode-locale-perl all 1.03-1 [12.4 kB]
# Get:58 http://archive.ubuntu.com/ubuntu/ trusty/main libfile-fcntllock-perl amd64 0.14-2build1 [15.9 kB]
# Get:59 http://archive.ubuntu.com/ubuntu/ trusty/main libhttp-date-perl all 6.02-1 [10.4 kB]
# Get:60 http://archive.ubuntu.com/ubuntu/ trusty/main libfile-listing-perl all 6.04-1 [9774 B]
# Get:61 http://archive.ubuntu.com/ubuntu/ trusty/main libfont-afm-perl all 1.20-1 [14.3 kB]
# Get:62 http://archive.ubuntu.com/ubuntu/ trusty/main liburi-perl all 1.60-1 [89.6 kB]
# Get:63 http://archive.ubuntu.com/ubuntu/ trusty/main libhtml-tagset-perl all 3.20-2 [13.5 kB]
# Get:64 http://archive.ubuntu.com/ubuntu/ trusty/main libhtml-parser-perl amd64 3.71-1build1 [98.2 kB]
# Get:65 http://archive.ubuntu.com/ubuntu/ trusty/main libio-html-perl all 1.00-1 [15.7 kB]
# Get:66 http://archive.ubuntu.com/ubuntu/ trusty/main liblwp-mediatypes-perl all 6.02-1 [21.7 kB]
# Get:67 http://archive.ubuntu.com/ubuntu/ trusty/main libhttp-message-perl all 6.06-1 [78.7 kB]
# Get:68 http://archive.ubuntu.com/ubuntu/ trusty/main libhtml-form-perl all 6.03-1 [23.5 kB]
# Get:69 http://archive.ubuntu.com/ubuntu/ trusty/main libhtml-tree-perl all 5.03-1 [215 kB]
# Get:70 http://archive.ubuntu.com/ubuntu/ trusty/main libhtml-format-perl all 2.11-1 [44.7 kB]
# Get:71 http://archive.ubuntu.com/ubuntu/ trusty/main libhttp-cookies-perl all 6.00-2 [23.3 kB]
# Get:72 http://archive.ubuntu.com/ubuntu/ trusty/main libhttp-daemon-perl all 6.01-1 [17.0 kB]
# Get:73 http://archive.ubuntu.com/ubuntu/ trusty/main libhttp-negotiate-perl all 6.00-2 [13.4 kB]
# Get:74 http://archive.ubuntu.com/ubuntu/ trusty/main libintl-perl all 1.23-1build1 [1204 kB]
# Get:75 http://archive.ubuntu.com/ubuntu/ trusty/main libsocket6-perl amd64 0.25-1 [23.5 kB]
# Get:76 http://archive.ubuntu.com/ubuntu/ trusty/main libio-socket-inet6-perl all 2.71-1 [14.6 kB]
# Get:77 http://archive.ubuntu.com/ubuntu/ trusty/main libnet-ssleay-perl amd64 1.58-1 [243 kB]
# Get:78 http://archive.ubuntu.com/ubuntu/ trusty/main libio-socket-ssl-perl all 1.965-1ubuntu1 [73.7 kB]
# Get:79 http://archive.ubuntu.com/ubuntu/ trusty/main libnet-http-perl all 6.06-1 [24.2 kB]
# Get:80 http://archive.ubuntu.com/ubuntu/ trusty/main libwww-robotrules-perl all 6.01-1 [14.1 kB]
# Get:81 http://archive.ubuntu.com/ubuntu/ trusty/main libwww-perl all 6.05-2 [146 kB]
# Get:82 http://archive.ubuntu.com/ubuntu/ trusty-updates/main liblwp-protocol-https-perl all 6.04-2ubuntu0.1 [7644 B]
# Get:83 http://archive.ubuntu.com/ubuntu/ trusty/main libnet-smtp-ssl-perl all 1.01-3 [5948 B]
# Get:84 http://archive.ubuntu.com/ubuntu/ trusty/main libmailtools-perl all 2.12-1 [84.1 kB]
# Get:85 http://archive.ubuntu.com/ubuntu/ trusty/main libtinfo-dev amd64 5.9+20140118-1ubuntu1 [76.3 kB]
# Get:86 http://archive.ubuntu.com/ubuntu/ trusty/main libreadline6-dev amd64 6.3-4ubuntu2 [213 kB]
# Get:87 http://archive.ubuntu.com/ubuntu/ trusty/main libreadline-dev amd64 6.3-4ubuntu2 [988 B]
# Get:88 http://archive.ubuntu.com/ubuntu/ trusty/main libtext-unidecode-perl all 0.04-2 [115 kB]
# Get:89 http://archive.ubuntu.com/ubuntu/ trusty/main libxml-namespacesupport-perl all 1.11-1 [13.2 kB]
# Get:90 http://archive.ubuntu.com/ubuntu/ trusty/main libxml-sax-base-perl all 1.07-1 [21.5 kB]
# Get:91 http://archive.ubuntu.com/ubuntu/ trusty/main libxml-sax-perl all 0.99+dfsg-2ubuntu1 [64.6 kB]
# Get:92 http://archive.ubuntu.com/ubuntu/ trusty-updates/main libxml-libxml-perl amd64 2.0108+dfsg-1ubuntu0.2 [336 kB]
# Get:93 http://archive.ubuntu.com/ubuntu/ trusty/main libxml-parser-perl amd64 2.41-1build3 [294 kB]
# Get:94 http://archive.ubuntu.com/ubuntu/ trusty/main libxml-sax-expat-perl all 0.40-2 [11.5 kB]
# Get:95 http://archive.ubuntu.com/ubuntu/ trusty/main manpages-dev all 3.54-1ubuntu1 [1820 kB]
# Get:96 http://archive.ubuntu.com/ubuntu/ trusty/main texinfo amd64 5.2.0.dfsg.1-2 [561 kB]
# Get:97 http://archive.ubuntu.com/ubuntu/ trusty/main libauthen-sasl-perl all 2.1500-1 [53.2 kB]
# Extracting templates from packages: 100%
# Fetched 51.4 MB in 11s (4404 kB/s)
# Selecting previously unselected package libedit2:amd64.
# (Reading database ... 14563 files and directories currently installed.)
# Preparing to unpack .../libedit2_3.1-20130712-2_amd64.deb ...
# Unpacking libedit2:amd64 (3.1-20130712-2) ...
# Selecting previously unselected package libxau6:amd64.
# Preparing to unpack .../libxau6_1%3a1.0.8-1_amd64.deb ...
# Unpacking libxau6:amd64 (1:1.0.8-1) ...
# Selecting previously unselected package libxdmcp6:amd64.
# Preparing to unpack .../libxdmcp6_1%3a1.1.1-1_amd64.deb ...
# Unpacking libxdmcp6:amd64 (1:1.1.1-1) ...
# Selecting previously unselected package libxcb1:amd64.
# Preparing to unpack .../libxcb1_1.10-2ubuntu1_amd64.deb ...
# Unpacking libxcb1:amd64 (1.10-2ubuntu1) ...
# Selecting previously unselected package libx11-data.
# Preparing to unpack .../libx11-data_2%3a1.6.2-1ubuntu2.1_all.deb ...
# Unpacking libx11-data (2:1.6.2-1ubuntu2.1) ...
# Selecting previously unselected package libx11-6:amd64.
# Preparing to unpack .../libx11-6_2%3a1.6.2-1ubuntu2.1_amd64.deb ...
# Unpacking libx11-6:amd64 (2:1.6.2-1ubuntu2.1) ...
# Selecting previously unselected package libxext6:amd64.
# Preparing to unpack .../libxext6_2%3a1.3.2-1ubuntu0.0.14.04.1_amd64.deb ...
# Unpacking libxext6:amd64 (2:1.3.2-1ubuntu0.0.14.04.1) ...
# Selecting previously unselected package libxml2:amd64.
# Preparing to unpack .../libxml2_2.9.1+dfsg1-3ubuntu4.13_amd64.deb ...
# Unpacking libxml2:amd64 (2.9.1+dfsg1-3ubuntu4.13) ...
# Selecting previously unselected package libxmuu1:amd64.
# Preparing to unpack .../libxmuu1_2%3a1.1.1-1_amd64.deb ...
# Unpacking libxmuu1:amd64 (2:1.1.1-1) ...
# Selecting previously unselected package sgml-base.
# Preparing to unpack .../sgml-base_1.26+nmu4ubuntu1_all.deb ...
# Unpacking sgml-base (1.26+nmu4ubuntu1) ...
# Selecting previously unselected package libsigsegv2:amd64.
# Preparing to unpack .../libsigsegv2_2.10-2_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.10-2) ...
# Setting up libsigsegv2:amd64 (2.10-2) ...
# Processing triggers for libc-bin (2.19-0ubuntu6.15) ...
# Selecting previously unselected package gawk.
# (Reading database ... 14898 files and directories currently installed.)
# Preparing to unpack .../gawk_1%3a4.0.1+dfsg-2.1ubuntu2_amd64.deb ...
# Unpacking gawk (1:4.0.1+dfsg-2.1ubuntu2) ...
# Selecting previously unselected package libasan0:amd64.
# Preparing to unpack .../libasan0_4.8.4-2ubuntu1~14.04.4_amd64.deb ...
# Unpacking libasan0:amd64 (4.8.4-2ubuntu1~14.04.4) ...
# Selecting previously unselected package libatomic1:amd64.
# Preparing to unpack .../libatomic1_4.8.4-2ubuntu1~14.04.4_amd64.deb ...
# Unpacking libatomic1:amd64 (4.8.4-2ubuntu1~14.04.4) ...
# Selecting previously unselected package libgmp10:amd64.
# Preparing to unpack .../libgmp10_2%3a5.1.3+dfsg-1ubuntu1_amd64.deb ...
# Unpacking libgmp10:amd64 (2:5.1.3+dfsg-1ubuntu1) ...
# Selecting previously unselected package libisl10:amd64.
# Preparing to unpack .../libisl10_0.12.2-1_amd64.deb ...
# Unpacking libisl10:amd64 (0.12.2-1) ...
# Selecting previously unselected package libcloog-isl4:amd64.
# Preparing to unpack .../libcloog-isl4_0.18.2-1_amd64.deb ...
# Unpacking libcloog-isl4:amd64 (0.18.2-1) ...
# Selecting previously unselected package libgomp1:amd64.
# Preparing to unpack .../libgomp1_4.8.4-2ubuntu1~14.04.4_amd64.deb ...
# Unpacking libgomp1:amd64 (4.8.4-2ubuntu1~14.04.4) ...
# Selecting previously unselected package libitm1:amd64.
# Preparing to unpack .../libitm1_4.8.4-2ubuntu1~14.04.4_amd64.deb ...
# Unpacking libitm1:amd64 (4.8.4-2ubuntu1~14.04.4) ...
# Selecting previously unselected package libmpfr4:amd64.
# Preparing to unpack .../libmpfr4_3.1.2-1_amd64.deb ...
# Unpacking libmpfr4:amd64 (3.1.2-1) ...
# Selecting previously unselected package libquadmath0:amd64.
# ...
# libtool: install: ranlib /usr/lib/libospf.a
# libtool: finish: PATH="/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/sbin" ldconfig -n /usr/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /usr/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the `-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the `LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the `LD_RUN_PATH' environment variable
#      during linking
#    - use the `-Wl,-rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to `/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
#  /bin/mkdir -p '/usr/lib/quagga'
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c ospfd '/usr/lib/quagga'
# libtool: install: /usr/bin/install -c .libs/ospfd /usr/lib/quagga/ospfd
#  /bin/mkdir -p '/usr/share/doc/quagga/examples/'
#  /usr/bin/install -c -m 644 ospfd.conf.sample '/usr/share/doc/quagga/examples/'
#  /bin/mkdir -p '/include/quagga/ospfd'
#  /usr/bin/install -c -m 644 ospf_api.h ospf_asbr.h ospf_dump.h ospf_lsa.h ospf_lsdb.h ospf_nsm.h ospf_ism.h ospf_opaque.h ospfd.h '/include/quagga/ospfd'
# make[2]: Leaving directory `/home/dev/quagga-1.0.20160315/ospfd'
# make[1]: Leaving directory `/home/dev/quagga-1.0.20160315/ospfd'
# Making install in ospf6d
# make[1]: Entering directory `/home/dev/quagga-1.0.20160315/ospf6d'
# make[2]: Entering directory `/home/dev/quagga-1.0.20160315/ospf6d'
#  /bin/mkdir -p '/usr/lib/quagga'
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c ospf6d '/usr/lib/quagga'
# libtool: install: /usr/bin/install -c .libs/ospf6d /usr/lib/quagga/ospf6d
#  /bin/mkdir -p '/usr/share/doc/quagga/examples/'
#  /usr/bin/install -c -m 644 ospf6d.conf.sample '/usr/share/doc/quagga/examples/'
# make[2]: Leaving directory `/home/dev/quagga-1.0.20160315/ospf6d'
# make[1]: Leaving directory `/home/dev/quagga-1.0.20160315/ospf6d'
# Making install in isisd
# make[1]: Entering directory `/home/dev/quagga-1.0.20160315/isisd'
# Making install in topology
# make[2]: Entering directory `/home/dev/quagga-1.0.20160315/isisd/topology'
# make[3]: Entering directory `/home/dev/quagga-1.0.20160315/isisd/topology'
# make[3]: Nothing to be done for `install-exec-am'.
# make[3]: Nothing to be done for `install-data-am'.
# make[3]: Leaving directory `/home/dev/quagga-1.0.20160315/isisd/topology'
# make[2]: Leaving directory `/home/dev/quagga-1.0.20160315/isisd/topology'
# make[2]: Entering directory `/home/dev/quagga-1.0.20160315/isisd'
# make[3]: Entering directory `/home/dev/quagga-1.0.20160315/isisd'
#  /bin/mkdir -p '/usr/lib/quagga'
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c isisd '/usr/lib/quagga'
# libtool: install: /usr/bin/install -c .libs/isisd /usr/lib/quagga/isisd
#  /bin/mkdir -p '/usr/share/doc/quagga/examples/'
#  /usr/bin/install -c -m 644 isisd.conf.sample '/usr/share/doc/quagga/examples/'
# make[3]: Leaving directory `/home/dev/quagga-1.0.20160315/isisd'
# make[2]: Leaving directory `/home/dev/quagga-1.0.20160315/isisd'
# make[1]: Leaving directory `/home/dev/quagga-1.0.20160315/isisd'
# Making install in pimd
# make[1]: Entering directory `/home/dev/quagga-1.0.20160315/pimd'
# make[2]: Entering directory `/home/dev/quagga-1.0.20160315/pimd'
#  /bin/mkdir -p '/usr/bin'
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c test_igmpv3_join '/usr/bin'
# libtool: install: /usr/bin/install -c test_igmpv3_join /usr/bin/test_igmpv3_join
#  /bin/mkdir -p '/usr/lib/quagga'
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c pimd '/usr/lib/quagga'
# libtool: install: /usr/bin/install -c .libs/pimd /usr/lib/quagga/pimd
#  /bin/mkdir -p '/usr/share/doc/quagga/examples/'
#  /usr/bin/install -c -m 644 pimd.conf.sample '/usr/share/doc/quagga/examples/'
# make[2]: Leaving directory `/home/dev/quagga-1.0.20160315/pimd'
# make[1]: Leaving directory `/home/dev/quagga-1.0.20160315/pimd'
# Making install in watchquagga
# make[1]: Entering directory `/home/dev/quagga-1.0.20160315/watchquagga'
# make[2]: Entering directory `/home/dev/quagga-1.0.20160315/watchquagga'
#  /bin/mkdir -p '/usr/lib/quagga'
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c watchquagga '/usr/lib/quagga'
# libtool: install: /usr/bin/install -c .libs/watchquagga /usr/lib/quagga/watchquagga
# make[2]: Nothing to be done for `install-data-am'.
# make[2]: Leaving directory `/home/dev/quagga-1.0.20160315/watchquagga'
# make[1]: Leaving directory `/home/dev/quagga-1.0.20160315/watchquagga'
# Making install in vtysh
# make[1]: Entering directory `/home/dev/quagga-1.0.20160315/vtysh'
# make[2]: Entering directory `/home/dev/quagga-1.0.20160315/vtysh'
#  /bin/mkdir -p '/usr/bin'
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c vtysh '/usr/bin'
# libtool: install: /usr/bin/install -c .libs/vtysh /usr/bin/vtysh
#  /bin/mkdir -p '/usr/share/doc/quagga/examples/'
#  /usr/bin/install -c -m 644 vtysh.conf.sample '/usr/share/doc/quagga/examples/'
# make[2]: Leaving directory `/home/dev/quagga-1.0.20160315/vtysh'
# make[1]: Leaving directory `/home/dev/quagga-1.0.20160315/vtysh'
# Making install in ospfclient
# make[1]: Entering directory `/home/dev/quagga-1.0.20160315/ospfclient'
# make[2]: Entering directory `/home/dev/quagga-1.0.20160315/ospfclient'
#  /bin/mkdir -p '/usr/lib'
#  /bin/bash ../libtool   --mode=install /usr/bin/install -c   libospfapiclient.la '/usr/lib'
# libtool: install: warning: relinking `libospfapiclient.la'
# libtool: install: (cd /home/dev/quagga-1.0.20160315/ospfclient; /bin/bash /home/dev/quagga-1.0.20160315/libtool  --silent --tag CC --mode=relink gcc -g -O2 -std=gnu99 -g -Os -fpie -fno-omit-frame-pointer -Wall -Wextra -Wmissing-prototypes -Wmissing-declarations -Wpointer-arith -Wbad-function-cast -Wwrite-strings -Wno-unused-result -Wno-unused-parameter -Wno-missing-field-initializers -version-info 0:0:0 -rdynamic -o libospfapiclient.la -rpath /usr/lib ospf_apiclient.lo ../ospfd/libospf.la ../lib/libzebra.la -lcrypt -lrt )
# libtool: install: /usr/bin/install -c .libs/libospfapiclient.so.0.0.0T /usr/lib/libospfapiclient.so.0.0.0
# libtool: install: (cd /usr/lib && { ln -s -f libospfapiclient.so.0.0.0 libospfapiclient.so.0 || { rm -f libospfapiclient.so.0 && ln -s libospfapiclient.so.0.0.0 libospfapiclient.so.0; }; })
# libtool: install: (cd /usr/lib && { ln -s -f libospfapiclient.so.0.0.0 libospfapiclient.so || { rm -f libospfapiclient.so && ln -s libospfapiclient.so.0.0.0 libospfapiclient.so; }; })
# libtool: install: /usr/bin/install -c .libs/libospfapiclient.lai /usr/lib/libospfapiclient.la
# libtool: install: /usr/bin/install -c .libs/libospfapiclient.a /usr/lib/libospfapiclient.a
# libtool: install: chmod 644 /usr/lib/libospfapiclient.a
# libtool: install: ranlib /usr/lib/libospfapiclient.a
# libtool: finish: PATH="/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/sbin" ldconfig -n /usr/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /usr/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the `-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the `LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the `LD_RUN_PATH' environment variable
#      during linking
#    - use the `-Wl,-rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to `/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
#  /bin/mkdir -p '/usr/lib/quagga'
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c ospfclient '/usr/lib/quagga'
# libtool: install: /usr/bin/install -c .libs/ospfclient /usr/lib/quagga/ospfclient
#  /bin/mkdir -p '/include/quagga/ospfapi'
#  /usr/bin/install -c -m 644 ospf_apiclient.h '/include/quagga/ospfapi'
# make[2]: Leaving directory `/home/dev/quagga-1.0.20160315/ospfclient'
# make[1]: Leaving directory `/home/dev/quagga-1.0.20160315/ospfclient'
# Making install in doc
# make[1]: Entering directory `/home/dev/quagga-1.0.20160315/doc'
# make  install-am
# make[2]: Entering directory `/home/dev/quagga-1.0.20160315/doc'
# make[3]: Entering directory `/home/dev/quagga-1.0.20160315/doc'
# make[3]: Nothing to be done for `install-exec-am'.
#  /bin/mkdir -p '/share/info'
#  /usr/bin/install -c -m 644 ./quagga.info ./quagga.info-1 ./quagga.info-2 '/share/info'
#  /bin/mkdir -p '/share/man/man1'
#  /usr/bin/install -c -m 644 vtysh.1 '/share/man/man1'
#  /bin/mkdir -p '/share/man/man8'
#  /usr/bin/install -c -m 644 pimd.8 bgpd.8 isisd.8 ospf6d.8 ospfclient.8 ospfd.8 ripd.8 ripngd.8 watchquagga.8 zebra.8 '/share/man/man8'
# make[3]: Leaving directory `/home/dev/quagga-1.0.20160315/doc'
# make[2]: Leaving directory `/home/dev/quagga-1.0.20160315/doc'
# make[1]: Leaving directory `/home/dev/quagga-1.0.20160315/doc'
# Making install in m4
# make[1]: Entering directory `/home/dev/quagga-1.0.20160315/m4'
# make[2]: Entering directory `/home/dev/quagga-1.0.20160315/m4'
# make[2]: Nothing to be done for `install-exec-am'.
# make[2]: Nothing to be done for `install-data-am'.
# make[2]: Leaving directory `/home/dev/quagga-1.0.20160315/m4'
# make[1]: Leaving directory `/home/dev/quagga-1.0.20160315/m4'
# Making install in redhat
# make[1]: Entering directory `/home/dev/quagga-1.0.20160315/redhat'
# make[2]: Entering directory `/home/dev/quagga-1.0.20160315/redhat'
# make[2]: Nothing to be done for `install-exec-am'.
# make[2]: Nothing to be done for `install-data-am'.
# make[2]: Leaving directory `/home/dev/quagga-1.0.20160315/redhat'
# make[1]: Leaving directory `/home/dev/quagga-1.0.20160315/redhat'
# Making install in tests
# make[1]: Entering directory `/home/dev/quagga-1.0.20160315/tests'
# make  install-recursive
# make[2]: Entering directory `/home/dev/quagga-1.0.20160315/tests'
# Making install in bgpd.tests
# make[3]: Entering directory `/home/dev/quagga-1.0.20160315/tests/bgpd.tests'
# make[4]: Entering directory `/home/dev/quagga-1.0.20160315/tests/bgpd.tests'
# make[4]: Nothing to be done for `install-exec-am'.
# make[4]: Nothing to be done for `install-data-am'.
# make[4]: Leaving directory `/home/dev/quagga-1.0.20160315/tests/bgpd.tests'
# make[3]: Leaving directory `/home/dev/quagga-1.0.20160315/tests/bgpd.tests'
# Making install in libzebra.tests
# make[3]: Entering directory `/home/dev/quagga-1.0.20160315/tests/libzebra.tests'
# make[4]: Entering directory `/home/dev/quagga-1.0.20160315/tests/libzebra.tests'
# make[4]: Nothing to be done for `install-exec-am'.
# make[4]: Nothing to be done for `install-data-am'.
# make[4]: Leaving directory `/home/dev/quagga-1.0.20160315/tests/libzebra.tests'
# make[3]: Leaving directory `/home/dev/quagga-1.0.20160315/tests/libzebra.tests'
# make[3]: Entering directory `/home/dev/quagga-1.0.20160315/tests'
# make[4]: Entering directory `/home/dev/quagga-1.0.20160315/tests'
# make[4]: Nothing to be done for `install-exec-am'.
# make[4]: Nothing to be done for `install-data-am'.
# make[4]: Leaving directory `/home/dev/quagga-1.0.20160315/tests'
# make[3]: Leaving directory `/home/dev/quagga-1.0.20160315/tests'
# make[2]: Leaving directory `/home/dev/quagga-1.0.20160315/tests'
# make[1]: Leaving directory `/home/dev/quagga-1.0.20160315/tests'
# make[1]: Entering directory `/home/dev/quagga-1.0.20160315'
# make[2]: Entering directory `/home/dev/quagga-1.0.20160315'
# make[2]: Nothing to be done for `install-exec-am'.
# make[2]: Nothing to be done for `install-data-am'.
# make[2]: Leaving directory `/home/dev/quagga-1.0.20160315'
# make[1]: Leaving directory `/home/dev/quagga-1.0.20160315'
# Removing intermediate container e42627d78b45
#  ---> a81bd92e77f7
# Step 12/37 : COPY corsa_cra/quagga/bgpd.conf /etc/quagga/bgpd.conf
#  ---> 4b2169095ed5
# Step 13/37 : COPY corsa_cra/quagga/zebra.conf /etc/quagga/zebra.conf
#  ---> f03b6c75b6ff
# Step 14/37 : COPY corsa_cra/quagga/vtysh.conf /etc/quagga/vtysh.conf
#  ---> 69a7a01c6f7d
# Step 15/37 : COPY corsa_cra/quagga/debian.conf /etc/quagga/debian.conf
#  ---> a6e1cbc0dc22
# Step 16/37 : COPY corsa_cra/quagga/etc_initd_quagga /etc/init.d/quagga
#  ---> 267a3a42ce41
# Step 17/37 : COPY corsa_cra/quagga/daemons /etc/quagga/daemons
#  ---> d87120380317
# Step 18/37 : COPY corsa_cra/cra/etc_corsa-app-cra.conf /etc/corsa-app-cra.conf
#  ---> c1b9cbc654f4
# Step 19/37 : COPY corsa_cra/cra/etc_initd_corsa-cra-app /etc/init.d/corsa-cra-app
#  ---> 0d4a0b5e0b68
# Step 20/37 : COPY corsa_cra/cra/etc_logrotated_corsa-cra-app /etc/logrotate.d/corsa-cra-app
#  ---> 8dfad0d8cf44
# Step 21/37 : COPY corsa_cra/cra/K10corsa-cra-app /etc/rc0.d/K10corsa-cra-app
#  ---> 7c46590b182b
# Step 22/37 : COPY corsa_cra/cra/K10corsa-cra-app /etc/rc1.d/K10corsa-cra-app
#  ---> 544207a5e8d1
# Step 23/37 : COPY corsa_cra/cra/K10corsa-cra-app /etc/rc6.d/K10corsa-cra-app
#  ---> 085347505d48
# Step 24/37 : COPY corsa_cra/cra/S90corsa-cra-app /etc/rc2.d/S90corsa-cra-app
#  ---> 2db7a88f23ea
# Step 25/37 : COPY corsa_cra/cra/S90corsa-cra-app /etc/rc3.d/S90corsa-cra-app
#  ---> 5d679c0d40f5
# Step 26/37 : COPY corsa_cra/cra/S90corsa-cra-app /etc/rc4.d/S90corsa-cra-app
#  ---> 19a870a33bc8
# Step 27/37 : COPY corsa_cra/cra/S90corsa-cra-app /etc/rc5.d/S90corsa-cra-app
#  ---> dd9171bf692d
# Step 28/37 : COPY corsa_cra/cra/usr_bin_corsa-cra-app /usr/bin/corsa-cra-app
#  ---> b8b0f08dce69
# Step 29/37 : COPY corsa_cra/cra/libcorsa_app.so.0.0.0 /usr/lib/x86_64-linux-gnu/libcorsa_app.so.0.0.0
#  ---> 6c39a559ebfd
# Step 30/37 : COPY corsa_cra/cra/libfluid_base.so.0.0.0 /usr/lib/x86_64-linux-gnu/libfluid_base.so.0.0.0
#  ---> ed20cdebbfaf
# Step 31/37 : COPY corsa_cra/cra/libfluid_msg.so.0.0.0 /usr/lib/x86_64-linux-gnu/libfluid_msg.so.0.0.0
#  ---> 4434469c0dd1
# Step 32/37 : COPY corsa_cra/cra/start_cra.sh start_cra.sh
#  ---> d7223a0aa2ef
# Step 33/37 : RUN chown quagga:quaggavty /etc/quagga/vtysh.conf
#  ---> Running in 0b71fc2e17f8
# Removing intermediate container 0b71fc2e17f8
#  ---> 76c75ba67643
# Step 34/37 : RUN mkdir /var/log/quagga && chown quagga: /var/log/quagga
#  ---> Running in eda55ab03f7c
# Removing intermediate container eda55ab03f7c
#  ---> daf692fa7b1c
# Step 35/37 : RUN cd /usr/lib/x86_64-linux-gnu  && ln -s libcorsa_app.so.0.0.0 libcorsa_app.so.0  && ln -s libfluid_base.so.0.0.0 libfluid_base.so.0  && ln -s libfluid_msg.so.0.0.0 libfluid_msg.so.0  && chown -R quagga.quagga /etc/quagga  && chmod +x /start_cra.sh
#  ---> Running in 40a3effcb99c
# Removing intermediate container 40a3effcb99c
#  ---> 4edd68f41207
# Step 36/37 : CMD echo "net.ipv4.conf.all.forwarding=1" | sudo tee -a /etc/sysctl.conf  && echo "net.ipv4.conf.default.forwarding=1" | sudo tee -a /etc/sysctl.conf  && sed 's/#net.ipv6.conf.all.forwarding=1/net.ipv6.conf.all.forwarding=1/g' /etc/sysctl.conf | sudo tee /etc/sysctl.conf  && echo "net.ipv6.conf.default.forwarding=1" | sudo tee -a /etc/sysctl.conf  && sudo sysctl -p   && echo "net.ipv4.conf.all.mc_forwarding=1" | sudo tee -a /etc/sysctl.conf  && echo "net.ipv4.conf.default.mc_forwarding=1" | sudo tee -a /etc/sysctl.conf  && sudo sysctl -p
#  ---> Running in 0b3733f3eb3e
# Removing intermediate container 0b3733f3eb3e
#  ---> 80f691ee8500
# Step 37/37 : CMD /start_cra.sh ; /bin/bash
#  ---> Running in 703b3cf1f487
# Removing intermediate container 703b3cf1f487
#  ---> bbacc4010dd2
# Successfully built bbacc4010dd2
# Successfully tagged cra_2:latest
# WARNING: Published ports are discarded when using host network mode
# 7bcb8fbfeae9e5ff42195b294901fe406ed4e0543e6ddb7e985aea8abdbe397c
# REPOSITORY          TAG                 IMAGE ID            CREATED             SIZE
# cra_2               latest              bbacc4010dd2        1 second ago        545MB
# ubuntu              14.04               df043b4f0cf1        8 days ago          197MB

# %% [markdown]
# ### Add local compute nodes
#
# At this point the internal network is

# %%
NODES_FLOATING_IP_LEASE_NAME="${USER}-Node-FloatingIP"

AMOUNT="1"

PUBLIC_NETWORK_ID=$(openstack network show public -f value -c id)

blazar lease-create \
  --reservation "resource_type=virtual:floatingip,network_id=${PUBLIC_NETWORK_ID},amount=${AMOUNT}" \
  "$NODES_FLOATING_IP_LEASE_NAME"
# Out:
# Matches: ('resource_type=virtual:floatingip,network_id=44b38c44-2a42-4b6d-b129-6c8f1b2a1375', 'amount', '1')
# Matches: ('resource_type=virtual:floatingip', 'network_id', '44b38c44-2a42-4b6d-b129-6c8f1b2a1375')
# Matches: (None, 'resource_type', 'virtual:floatingip')
# Created a new lease:
# +--------------+------------------------------------------------------------------+
# | Field        | Value                                                            |
# +--------------+------------------------------------------------------------------+
# | created_at   | 2020-09-25 16:22:15                                              |
# | degraded     | False                                                            |
# | end_date     | 2020-09-26T16:22:00.000000                                       |
# | events       | {                                                                |
# |              |     "status": "UNDONE",                                          |
# |              |     "lease_id": "a33ca7fd-1644-41e0-a0f4-fcb2e7f1ba6d",          |
# |              |     "event_type": "start_lease",                                 |
# |              |     "created_at": "2020-09-25 16:22:16",                         |
# |              |     "updated_at": null,                                          |
# |              |     "time": "2020-09-25T16:22:00.000000",                        |
# |              |     "id": "306bb445-1cb0-4a84-9754-e7779bc54e0e"                 |
# |              | }                                                                |
# |              | {                                                                |
# |              |     "status": "UNDONE",                                          |
# |              |     "lease_id": "a33ca7fd-1644-41e0-a0f4-fcb2e7f1ba6d",          |
# |              |     "event_type": "end_lease",                                   |
# |              |     "created_at": "2020-09-25 16:22:16",                         |
# |              |     "updated_at": null,                                          |
# |              |     "time": "2020-09-26T16:22:00.000000",                        |
# |              |     "id": "7832000d-b597-430b-9e72-876cbfde8e5a"                 |
# |              | }                                                                |
# |              | {                                                                |
# |              |     "status": "UNDONE",                                          |
# |              |     "lease_id": "a33ca7fd-1644-41e0-a0f4-fcb2e7f1ba6d",          |
# |              |     "event_type": "before_end_lease",                            |
# |              |     "created_at": "2020-09-25 16:22:16",                         |
# |              |     "updated_at": null,                                          |
# |              |     "time": "2020-09-25T16:22:00.000000",                        |
# |              |     "id": "fd307096-4f92-492f-afb4-e5bc3f722528"                 |
# |              | }                                                                |
# | id           | a33ca7fd-1644-41e0-a0f4-fcb2e7f1ba6d                             |
# | name         | pruth-Node-FloatingIP                                            |
# | project_id   | 4b6fc5a731a54b6f932b200050f13b54                                 |
# | reservations | {                                                                |
# |              |     "status": "pending",                                         |
# |              |     "lease_id": "a33ca7fd-1644-41e0-a0f4-fcb2e7f1ba6d",          |
# |              |     "resource_id": "5a0a1d0f-acb9-449a-8511-35293be5f2a4",       |
# |              |     "network_id": "44b38c44-2a42-4b6d-b129-6c8f1b2a1375",        |
# |              |     "created_at": "2020-09-25 16:22:15",                         |
# |              |     "updated_at": "2020-09-25 16:22:16",                         |
# |              |     "required_floatingips": [],                                  |
# |              |     "missing_resources": false,                                  |
# |              |     "amount": 1,                                                 |
# |              |     "id": "082845aa-c257-40bd-8899-6a27d3cf73d6",                |
# |              |     "resource_type": "virtual:floatingip",                       |
# |              |     "resources_changed": false                                   |
# |              | }                                                                |
# | start_date   | 2020-09-25T16:22:00.000000                                       |
# | status       | PENDING                                                          |
# | trust_id     | 1d358a9740f34ff08a9a1c7018a6b010                                 |
# | updated_at   | 2020-09-25 16:22:16                                              |
# | user_id      | 02276834a17c4ca205d49eaa8c984eeaefc24c153f8a62bc16e5f880e7cce607 |
# +--------------+------------------------------------------------------------------+

# %% [markdown]
# #### Create servers on the new network
#
# You can now create Chameleon nodes on the internal network that will be able to communicate over the CloudConnect link that we will create later in this tutorial. Any nodes can be created on the internal network. The example creates a single x86 haswell node.

# %%
# Create Lease for the BGP router.
# Requires 1 Haswell Node with dual-NICs enabled
#
NODES_LEASE_NAME="${USER}-AWS-Nodes-Lease" 

NODE_TYPE="compute_haswell"
MIN=1
MAX=1

blazar lease-create \
      --physical-reservation min=${MIN},max=${MAX},resource_properties="[\"==\",\"\$node_type\",\"compute_haswell\"]" \
      ${NODES_LEASE_NAME}
# Out:
# Matches: ('min=1,max=1', 'resource_properties', '["==","$node_type","compute_haswell"]')
# Matches: ('min=1', 'max', '1')
# Matches: (None, 'min', '1')
# Created a new lease:
# +--------------+---------------------------------------------------------------------------+
# | Field        | Value                                                                     |
# +--------------+---------------------------------------------------------------------------+
# | created_at   | 2020-09-25 16:22:27                                                       |
# | degraded     | False                                                                     |
# | end_date     | 2020-09-26T16:22:00.000000                                                |
# | events       | {                                                                         |
# |              |     "status": "UNDONE",                                                   |
# |              |     "lease_id": "c2eae580-1dff-47ca-8883-baedf8e17e5d",                   |
# |              |     "event_type": "start_lease",                                          |
# |              |     "created_at": "2020-09-25 16:22:36",                                  |
# |              |     "updated_at": null,                                                   |
# |              |     "time": "2020-09-25T16:22:00.000000",                                 |
# |              |     "id": "35605333-a0e4-4c97-9839-cc1ce3e26fdb"                          |
# |              | }                                                                         |
# |              | {                                                                         |
# |              |     "status": "UNDONE",                                                   |
# |              |     "lease_id": "c2eae580-1dff-47ca-8883-baedf8e17e5d",                   |
# |              |     "event_type": "before_end_lease",                                     |
# |              |     "created_at": "2020-09-25 16:22:36",                                  |
# |              |     "updated_at": null,                                                   |
# |              |     "time": "2020-09-25T16:22:00.000000",                                 |
# |              |     "id": "3f3e689c-5af5-49dd-a621-ea9bf053e57a"                          |
# |              | }                                                                         |
# |              | {                                                                         |
# |              |     "status": "UNDONE",                                                   |
# |              |     "lease_id": "c2eae580-1dff-47ca-8883-baedf8e17e5d",                   |
# |              |     "event_type": "end_lease",                                            |
# |              |     "created_at": "2020-09-25 16:22:36",                                  |
# |              |     "updated_at": null,                                                   |
# |              |     "time": "2020-09-26T16:22:00.000000",                                 |
# |              |     "id": "765fadf4-3426-4d56-8275-c3c7b8b9b24d"                          |
# |              | }                                                                         |
# | id           | c2eae580-1dff-47ca-8883-baedf8e17e5d                                      |
# | name         | pruth-AWS-Nodes-Lease                                                     |
# | project_id   | 4b6fc5a731a54b6f932b200050f13b54                                          |
# | reservations | {                                                                         |
# |              |     "status": "pending",                                                  |
# |              |     "before_end": "default",                                              |
# |              |     "lease_id": "c2eae580-1dff-47ca-8883-baedf8e17e5d",                   |
# |              |     "resource_id": "59841639-709d-4f9a-9c55-01e04f8975f2",                |
# |              |     "max": 1,                                                             |
# |              |     "created_at": "2020-09-25 16:22:27",                                  |
# |              |     "min": 1,                                                             |
# |              |     "updated_at": "2020-09-25 16:22:36",                                  |
# |              |     "missing_resources": false,                                           |
# |              |     "hypervisor_properties": "",                                          |
# |              |     "on_start": "default",                                                |
# |              |     "resource_properties": "[\"==\",\"$node_type\",\"compute_haswell\"]", |
# |              |     "id": "5040bb85-971d-49df-9465-77fbeca070bf",                         |
# |              |     "resource_type": "physical:host",                                     |
# |              |     "resources_changed": false                                            |
# |              | }                                                                         |
# | start_date   | 2020-09-25T16:22:00.000000                                                |
# | status       | PENDING                                                                   |
# | trust_id     | c3bf94acd9064285916adf5bdddf863f                                          |
# | updated_at   | 2020-09-25 16:22:36                                                       |
# | user_id      | 02276834a17c4ca205d49eaa8c984eeaefc24c153f8a62bc16e5f880e7cce607          |
# +--------------+---------------------------------------------------------------------------+

# %%
# Get the reservation ID
NODES_RESERVATION_ID=$(blazar lease-show  -f json ${NODES_LEASE_NAME} | jq -r .reservations | jq -r .id)
NODES_LEASE_ID=$(blazar lease-show  -f json ${NODES_LEASE_NAME} | jq -r .id)

# Get network UUIDs
NET_UUID_INTERNAL=$( openstack network show -f value -c id ${INTERNAL_NET_NAME} )

NODES_NAME="${USER}-Node" 

FLAVOR="baremetal"
IMAGE="CC-CentOS7"

openstack server create \
  --image ${IMAGE} \
  --flavor ${FLAVOR} \
  --key-name ${KEY_NAME} \
  --nic net-id=${NET_UUID_INTERNAL} \
  --hint reservation=${NODES_RESERVATION_ID} \
  --hint query='["=","$hypervisor_hostname","$PHYSICAL"]' \
  ${NODES_NAME}
# Out:
# +-------------------------------------+------------------------------------------------------------------+
# | Field                               | Value                                                            |
# +-------------------------------------+------------------------------------------------------------------+
# | OS-DCF:diskConfig                   | MANUAL                                                           |
# | OS-EXT-AZ:availability_zone         |                                                                  |
# | OS-EXT-SRV-ATTR:host                | None                                                             |
# | OS-EXT-SRV-ATTR:hypervisor_hostname | None                                                             |
# | OS-EXT-SRV-ATTR:instance_name       |                                                                  |
# | OS-EXT-STS:power_state              | NOSTATE                                                          |
# | OS-EXT-STS:task_state               | scheduling                                                       |
# | OS-EXT-STS:vm_state                 | building                                                         |
# | OS-SRV-USG:launched_at              | None                                                             |
# | OS-SRV-USG:terminated_at            | None                                                             |
# | accessIPv4                          |                                                                  |
# | accessIPv6                          |                                                                  |
# | addresses                           |                                                                  |
# | adminPass                           | KGSb3VRdZwi9                                                     |
# | config_drive                        |                                                                  |
# | created                             | 2020-09-25T16:23:21Z                                             |
# | flavor                              | baremetal (baremetal)                                            |
# | hostId                              |                                                                  |
# | id                                  | 75f08fb0-be8f-43eb-aa3c-73cc07eaf932                             |
# | image                               | CC-CentOS7 (2feec1df-8523-4a82-92f2-19c39224fa89)                |
# | key_name                            | my_chameleon_key                                                 |
# | name                                | pruth-Node                                                       |
# | progress                            | 0                                                                |
# | project_id                          | 4b6fc5a731a54b6f932b200050f13b54                                 |
# | properties                          |                                                                  |
# | security_groups                     | name='default'                                                   |
# | status                              | BUILD                                                            |
# | updated                             | 2020-09-25T16:23:21Z                                             |
# | user_id                             | 02276834a17c4ca205d49eaa8c984eeaefc24c153f8a62bc16e5f880e7cce607 |
# | volumes_attached                    |                                                                  |
# +-------------------------------------+------------------------------------------------------------------+

# %%
NODE_FLOATING_IP=$(lease_list_floating_ips "$NODES_FLOATING_IP_LEASE_NAME" | sed -n 1p)

openstack server add floating ip "$NODES_NAME" "$NODE_FLOATING_IP" \
  && echo "Attached floating ip $NODE_FLOATING_IP!"
# Out:
# Attached floating ip 192.5.87.211!

# %% [markdown]
# It is probably worth configuring the node with jumbo frames for better performance. The following shows the network tuning we used to get the most bandwidth. These tunning parameters are recommended by [ESnet](https://fasterdata.es.net/host-tuning/linux/).

# %%
login_command="ssh -o \"StrictHostKeyChecking no\" -i $PRIVATE_KEY_LOCATION cc@$NODE_FLOATING_IP"

eval "$login_command bash << EOF

sudo ip link set eth0 mtu 9000
sudo ip link set eth0 txqueuelen 10000

# allow testing with buffers up to 64MB 

sudo sh -c 'echo net.core.rmem_max = 67108864 >> /etc/sysctl.conf'
sudo sh -c 'echo net.core.wmem_max = 67108864  >> /etc/sysctl.conf'
sudo sh -c 'echo net.ipv4.tcp_rmem = 4096 87380 33554432 >> /etc/sysctl.conf'
sudo sh -c 'echo net.ipv4.tcp_wmem = 4096 65536 33554432 >> /etc/sysctl.conf'
sudo sh -c 'echo net.ipv4.tcp_congestion_control=htcp >> /etc/sysctl.conf'
sudo sh -c 'echo net.ipv4.tcp_mtu_probing=1 >> /etc/sysctl.conf'
sudo sh -c 'echo net.core.default_qdisc = fq >> /etc/sysctl.conf'

sudo sysctl -p 

EOF"
# Out:
# Warning: Permanently added '192.5.87.211' (ECDSA) to the list of known hosts.
# net.core.rmem_max = 67108864
# net.core.wmem_max = 67108864
# net.ipv4.tcp_rmem = 4096 87380 33554432
# net.ipv4.tcp_wmem = 4096 65536 33554432
# net.ipv4.tcp_congestion_control = htcp
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq

# %% [markdown]
# ### Internet2 CloudConnect
#
# The Internet2 CloudConnect connection must be created by an authorized administrator. We would be happy to create this connection for you. Please create a Chameleon support ticket and cut/paste the output of the following cell.
#
# You will need to add your AWS account number and the desired bandwith.
#
# If you are an authorized CloudConnect user and would like to be able to create your own links, please create a support ticket and we can disscuss support your request.

# %%
DIRECTSTITCH_VLAN=`openstack network show -c provider:segmentation_id -f value ${EXTERNAL_NET_NAME}`

echo Bandwidth: See: https://aws.amazon.com/directconnect/pricing/
echo Connection Name: $DIRECT_CONNECT_NAME

echo AWS Account ID: Your AWS Account Number
echo AWS VLAN: $AWS_VLAN
echo AWS ASN: $AWS_ASN
echo AWS Router Extenal IP: $AWS_ROUTER_EXTERNAL_IP
echo Internet2 IP Facing AWS: $INTERNET2_ROUTER_IP_FACING_AWS
echo AWS Subnet: $AWS_SUBNET
echo AWS BGP Key: $AWS_BGP_PASSWORD

echo Chameleon network VLAN: $DIRECTSTITCH_VLAN
echo Chameleon Router External IP: $CHAMELEON_ROUTER_IP_FACING_INTERNET2
echo Internet2 IP Facing AWS: $INTERNET2_ROUTER_IP_FACING_CHAMELEON
echo Chameleon Router External SUBNET: $EXTERNAL_SUBNET
echo Chameleon ASN: $CHAMELEON_ASN
echo Chameleon Router AuthPassword: $CHAMELEON_BGP_PASSWORD
echo Chameleon Region: $OS_REGION_NAME
# Out:
# Unauthorized (HTTP 401)
# Bandwidth: See: https://aws.amazon.com/directconnect/pricing/
# Connection Name: Chameleon_Direct_Connect
# AWS Account ID: Your AWS Account Number
# AWS VLAN: 10
# AWS ASN: 65001
# AWS Router Extenal IP: 192.168.3.2
# Internet2 IP Facing AWS:
# AWS Subnet:
# AWS BGP Key: BgpAuthPass
# Chameleon network VLAN:
# Chameleon Router External IP:
# Internet2 IP Facing AWS:
# Chameleon Router External SUBNET: 192.168.3.0/24
# Chameleon ASN: 65002
# Chameleon Router AuthPassword: BgpAuthPass
# Chameleon Region: CHI@UC

# %% [markdown]
# ### Set up AWS Direct Connect Connection

# %%
#sudo yum -y install awscli

AWS_ACCESS_KEY_ID=`tail -n +2  ~/work/new_user_credentials.csv | cut -d, -f1`
AWS_SECRRET_ACCESS_KEY=`tail -n +2  ~/work/new_user_credentials.csv | cut -d, -f2`

DEFAULT_REGION_NAME='us-east-2'
DEFAULT_OUTPUT_FORMAT='json'


# Note: can be done internativly with 'aws configure'
aws configure set aws_access_key_id $AWS_ACCESS_KEY_ID
aws configure set aws_secret_access_key $AWS_SECRRET_ACCESS_KEY
aws configure set default.region $DEFAULT_REGION_NAME
aws configure set default.output $DEFAULT_OUTPUT_FORMAT

# %%
#Needs try/catch b/c some vpcs don't have Tags/Names
VPC_ID=`aws --output json ec2 describe-vpcs | jq -r '.Vpcs[] | try if .Tags[].Key == "Name" and .Tags[].Value == "'${AWS_VPC_NAME}'" then .VpcId else "" end catch ""'`

echo VPC_ID $VPC_ID
# Out:
# VPC_ID vpc-095801bc19a70cdbc

# %%
#Create VPG
VPC_GATEWAY_ID=`aws --output json ec2 create-vpn-gateway --type ipsec.1 --amazon-side-asn 65001 | jq -r '.VpnGateway.VpnGatewayId'`
echo VPC_GATEWAY_ID $VPC_GATEWAY_ID
# Out:
# VPC_GATEWAY_ID vgw-0939d968c1d9b3665

# %%
#Attach VPG to VPC
aws --output json ec2 attach-vpn-gateway --vpc-id $VPC_ID --vpn-gateway-id $VPC_GATEWAY_ID
# Out:
# {
#     "VpcAttachment": {
#         "State": "attaching",
#         "VpcId": "vpc-095801bc19a70cdbc"
#     }
# }

# %%
ROUTE_TABLE_ID=`aws --output json ec2 describe-route-tables | jq -r '.RouteTables[] |  try if .VpcId == "'${VPC_ID}'" then .RouteTableId else "" end catch ""'`
echo ROUTE_TABLE_ID $ROUTE_TABLE_ID
# Out:
# ROUTE_TABLE_ID rtb-0434d4438f34a2460

# %%
aws --output json ec2 enable-vgw-route-propagation --gateway-id $VPC_GATEWAY_ID \
                                                   --route-table-id $ROUTE_TABLE_ID

# %%
#Get directconnect conneciton id
DIRECT_CONNECT_ID=`aws --output json directconnect describe-connections | jq -r '.connections[] |  try if .connectionName == "'${DIRECT_CONNECT_NAME}'" then .connectionId else "" end catch ""'`
echo DIRECTCONNECT_ID $DIRECT_CONNECT_ID
# Out:
# DIRECTCONNECT_ID dxcon-fh173erj

# %%
aws --output json directconnect confirm-connection --connection-id $DIRECT_CONNECT_ID
# Out:
# {
#     "connectionState": "pending"
# }

# %%
DIRECT_CONNECT_STATE=""

while [ "$DIRECT_CONNECT_STATE" != "available" ]
do 
    sleep 10
    #Needs try/catch b/c some instnaces don't have Tags/Names
    DIRECT_CONNECT_STATE=`aws --output json directconnect describe-connections | jq -r '.connections[] |  try if .connectionName == "'${DIRECT_CONNECT_NAME}'" then .connectionState else "" end catch ""'`
    echo DIRECTCONNECT_STATE $DIRECT_CONNECT_STATE
done
# Out:
# DIRECTCONNECT_STATE pending
# DIRECTCONNECT_STATE available

# %%
#Create DirectConnectGateway
DIRECT_CONNECT_GATEWAY_NAME="dcgw-"${DIRECT_CONNECT_NAME} 

aws --output json directconnect create-direct-connect-gateway --direct-connect-gateway-name $DIRECT_CONNECT_GATEWAY_NAME --amazon-side-asn $AWS_ASN
# Out:
# {
#     "directConnectGateway": {
#         "directConnectGatewayId": "85cca4bb-770a-4747-8f22-9227f85a946c",
#         "directConnectGatewayName": "dcgw-Chameleon_Direct_Connect",
#         "amazonSideAsn": 65001,
#         "ownerAccount": "370592084203",
#         "directConnectGatewayState": "available"
#     }
# }

# %%
#Needs try/catch b/c some instnaces don't have Tags/Names
DIRECT_CONNECT_GW_ID=`aws --output json directconnect describe-direct-connect-gateways | jq -r '.directConnectGateways[] |  try if .directConnectGatewayName == "'${DIRECT_CONNECT_GATEWAY_NAME}'" then .directConnectGatewayId else "" end catch ""'`
echo DIRECTCONNECT_GW_ID $DIRECT_CONNECT_GW_ID
# Out:
# DIRECTCONNECT_GW_ID 85cca4bb-770a-4747-8f22-9227f85a946c

# %%
#Create VirtualPrivateGateway
VIRTUAL_INTERFACE_NAME="vif-"${DIRECT_CONNECT_NAME} 

MTU=9001

aws --output json directconnect create-private-virtual-interface \
                                          --connection-id $DIRECT_CONNECT_ID \
                                          --new-private-virtual-interface virtualInterfaceName=${VIRTUAL_INTERFACE_NAME},vlan=${AWS_VLAN},asn=${CHAMELEON_ASN},authKey=${BGP_PASSWORD},mtu=${MTU},amazonAddress=${AWS_ROUTER_EXTERNAL_IP_CIDR},customerAddress=${CHAMELEON_ROUTER_IP_FACING_AWS_CIDR},directConnectGatewayId=${DIRECT_CONNECT_GW_ID}
# Out:
# {
#     "ownerAccount": "370592084203",
#     "virtualInterfaceId": "dxvif-fgzvrw7f",
#     "location": "EQC50",
#     "connectionId": "dxcon-fh173erj",
#     "virtualInterfaceType": "private",
#     "virtualInterfaceName": "vif-Chameleon_Direct_Connect",
#     "vlan": 10,
#     "asn": 65002,
#     "amazonSideAsn": 65001,
#     "authKey": "BgpAuthPass",
#     "amazonAddress": "192.168.3.2/24",
#     "customerAddress": "192.168.3.1/24",
#     "addressFamily": "ipv4",
#     "virtualInterfaceState": "pending",
#     "customerRouterConfig": "<?xml version=\"1.0\" encoding=\"UTF-8\"?>\n<logical_connection id=\"dxvif-fgzvrw7f\">\n  <vlan>10</vlan>\n  <customer_address>192.168.3.1/24</customer_address>\n  <amazon_address>192.168.3.2/24</amazon_address>\n  <bgp_asn>65002</bgp_asn>\n  <bgp_auth_key>BgpAuthPass</bgp_auth_key>\n  <amazon_bgp_asn>65001</amazon_bgp_asn>\n  <connection_type>private</connection_type>\n</logical_connection>\n",
#     "mtu": 9001,
#     "jumboFrameCapable": true,
#     "virtualGatewayId": "",
#     "directConnectGatewayId": "85cca4bb-770a-4747-8f22-9227f85a946c",
#     "routeFilterPrefixes": [],
#     "bgpPeers": [
#         {
#             "bgpPeerId": "dxpeer-fgpmck5u",
#             "asn": 65002,
#             "authKey": "BgpAuthPass",
#             "addressFamily": "ipv4",
#             "amazonAddress": "192.168.3.2/24",
#             "customerAddress": "192.168.3.1/24",
#             "bgpPeerState": "pending",
#             "bgpStatus": "down",
#             "awsDeviceV2": "EQC50-3owlkuwy6ujjd"
#         }
#     ],
#     "region": "us-east-2",
#     "awsDeviceV2": "EQC50-3owlkuwy6ujjd",
#     "tags": []
# }

# %%
#Associate VPGW with DirectConnect GW

aws --output json  directconnect create-direct-connect-gateway-association --direct-connect-gateway-id $DIRECT_CONNECT_GW_ID \
                                                                           --virtual-gateway-id $VPC_GATEWAY_ID
# Out:
# {
#     "directConnectGatewayAssociation": {
#         "directConnectGatewayId": "85cca4bb-770a-4747-8f22-9227f85a946c",
#         "directConnectGatewayOwnerAccount": "370592084203",
#         "associationState": "associating",
#         "associatedGateway": {
#             "id": "vgw-0939d968c1d9b3665",
#             "type": "virtualPrivateGateway",
#             "ownerAccount": "370592084203",
#             "region": "us-east-2"
#         },
#         "associationId": "ec12df56-fbdb-4870-8703-e504a4d3feb9",
#         "allowedPrefixesToDirectConnectGateway": [
#             {
#                 "cidr": "192.168.1.0/24"
#             }
#         ],
#         "virtualGatewayId": "vgw-0939d968c1d9b3665",
#         "virtualGatewayRegion": "us-east-2",
#         "virtualGatewayOwnerAccount": "370592084203"
#     }
# }
